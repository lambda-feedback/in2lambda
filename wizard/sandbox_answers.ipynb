# %%
import os
import re
import json

from pathlib import Path
from io import BytesIO
from dotenv import load_dotenv
from pydantic import BaseModel, Field

from langchain.document_loaders import UnstructuredPDFLoader
from langchain.docstore.document import Document
from langchain_openai import AzureChatOpenAI
from langchain.output_parsers import PydanticOutputParser
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_openai import ChatOpenAI


import fitz  # PyMuPDF
from PIL import Image
import pytesseract

# %%
def convert_math_to_markdown(text: str, llm) -> str:
    """
    Uses the LLM to convert scientific text (including mathematics)
    into markdown (e.g. wrapping inline math with $ or display math with $$).
    """
    prompt = (
        "Convert the following scientific text with mathematics into markdown format. "
        "Ensure that all mathematical expressions are properly formatted using inline ($...$) "
        "markdown syntax as appropriate.\n\n"
        f"{text}"
    )
    markdown_text = llm.invoke(prompt)
    return markdown_text.content


def extract_caption_from_bbox(page, bbox, threshold: float = 50) -> str:
    caption_candidates = []
    # Iterate over each block.
    for block in page.get_text("blocks"):
        # Unpack the first five elements and ignore the rest.
        bx0, by0, bx1, by1, text, *_ = block
        if not text.strip():
            continue
        # If the block's top coordinate is just below the image bounding box.
        if by0 >= bbox[3] and (by0 - bbox[3]) < threshold:
            caption_candidates.append((by0, text.strip()))
    if caption_candidates:
        # Return the caption of the block closest to the image.
        caption_candidates.sort(key=lambda t: t[0])
        return caption_candidates[0][1]
    return None


def parse_caption(caption: str) -> (str, str):
    """
    Given a caption string, try to parse out a title and label.
    For example, if the caption includes tokens like “Title: …” or “Label: …”.
    """
    title = ""
    label = ""
    m_title = re.search(r"Title\s*[:\-]\s*(.+?)(,|$)", caption, re.IGNORECASE)
    if m_title:
        title = m_title.group(1).strip()
    m_label = re.search(r"Label\s*[:\-]\s*(.+?)(,|$)", caption, re.IGNORECASE)
    if m_label:
        label = m_label.group(1).strip()
    return title, label


def get_figure_name(caption: str, default_name: str) -> str:
    """
    If the caption contains a reference like “Figure 2”, return a name based on that.
    Otherwise return the provided default name.
    """
    if caption:
        m_fig = re.search(r"Figure\s*(\d+)", caption, re.IGNORECASE)
        if m_fig:
            return f"Figure_{m_fig.group(1)}"
    return default_name


def process_pdf(pdf_path: str, llm):
    """
    Reads a PDF file, extracts its text (with mathematics converted to markdown)
    and extracts images (with associated captions parsed for title and label).
    
    Returns a LangChain Document whose page_content is the markdown text and whose
    metadata includes a dictionary 'figures' mapping figure names to a dict:
      { "image": <PIL.Image>, "title": <str>, "label": <str> }.
    """
    # 1. Extract the main text using a loader optimized for scientific content.
    text_loader = UnstructuredPDFLoader(pdf_path)
    docs = text_loader.load()
    combined_text = "\n".join(doc.page_content for doc in docs)
    
    # Ignire the first page if it contains a title.
    if len(docs) > 1 and docs[0].page_content.strip() == docs[1].page_content.strip():
        combined_text = "\n".join(doc.page_content for doc in docs[1:])
    # Remove any leading or trailing whitespace.
    combined_text = combined_text.strip()

    # Stop processing text after "Appendices"
    appendices_index = combined_text.find("Notes on the Paper")
    if appendices_index != -1:
        combined_text = combined_text[:appendices_index]
    
    # Remove the [number%]
    combined_text = re.sub(r"\[\d+%\]", "", combined_text)
    
    # 2. Use the LLM to convert mathematics in the text to proper markdown.
    markdown_text = convert_math_to_markdown(combined_text, llm)
    
    # 3. Extract images and associated metadata using PyMuPDF.
    pdf_doc = fitz.open(pdf_path)
    figures = {}
    
    for page_num in range(len(pdf_doc)):
        page = pdf_doc[page_num]
        # Use the "dict" interface for richer info.
        page_dict = page.get_text("dict")
        blocks = page_dict.get("blocks", [])

        # Extract embedded images
        images = page.get_images(full=True)
        for img_index, img in enumerate(images):
            xref = img[0]
            base_image = pdf_doc.extract_image(xref)
            image_bytes = base_image["image"]
            img_obj = Image.open(BytesIO(image_bytes))
            img_obj.save(f"media_ans/page_{page_num + 1}_img_{img_index}.png")

        for block in blocks:
            if isinstance(block, dict) and block.get("type") == 1:
                xref = block.get("image")
                bbox = block.get("bbox")
                if not xref:
                    continue

                # Check the type of xref.
                if isinstance(xref, int):
                    # xref is valid; extract the image using PyMuPDF.
                    base_image = pdf_doc.extract_image(xref)
                    image_bytes = base_image["image"]
                elif isinstance(xref, bytes):
                    # xref already contains the image bytes (inline image).
                    image_bytes = xref
                else:
                    continue

                # Open the image with PIL.
                img_obj = Image.open(BytesIO(image_bytes))
                
                # Try to extract a caption near the image.
                caption = extract_caption_from_bbox(page, bbox)
                title, label = ("", "")
                if caption:
                    title, label = parse_caption(caption)
                default_fig_name = f"page{page_num+1}_img_{xref if isinstance(xref, int) else 'inline'}"
                fig_name = get_figure_name(caption, default_fig_name) if caption else default_fig_name
                figures[fig_name] = {"image": img_obj, "title": title, "label": label}
    
    pdf_doc.close()
    
    # 4. Create and return a LangChain Document.
    metadata = {"figures": figures}
    final_doc = Document(page_content=markdown_text, metadata=metadata)
    return final_doc

# %%
# Load environment variables from .env file.
load_dotenv()

# Set up the Azure OpenAI LLM via LangChain.
temperature = 0
llm = ChatOpenAI(
            model=os.environ['OPENAI_MODEL'],
            api_key=os.environ["OPENAI_API_KEY"],
        )
# llm = ChatGoogleGenerativeAI(
#             model=os.environ['GOOGLE_AI_MODEL'],
#             temperature=temperature,
#             google_api_key=os.environ['GOOGLE_AI_API_KEY'],
#         )

pdf_file_path = "pastpapers/2023_answers.pdf"
doc = process_pdf(pdf_file_path, llm)

# Print out a summary.
print("Markdown text: ")
print(doc.page_content)

# Needs to be improved to infer name/label/caption based on context.
figures = doc.metadata.get("figures", {})
print("\nExtracted figures:")

Path("media").mkdir(exist_ok=True)
for idx, (fig_name, fig_info) in enumerate(figures.items()):
    print(f"  {fig_name}: Title='{fig_info['title']}', Label='{fig_info['label']}'")
    # Save each image as a PNG file with a sequential name: figure_0.png, figure_1.png, etc.
    fig_info["image"].save(f"media_ans/figure_{idx}.png")
# Out:
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# Markdown text:
# Below is the converted text in Markdown format with all mathematical expressions formatted using inline ($…$) or display ($$ … $$) mathematics as appropriate.
#
# ---
#
# # ME2–FMX 2023 Exam-Paper Solutions
# A. Giusti, P. Johnson
#
# ## Question 1
#
# ### Soap Dispenser
#
# **(a)**
#
# The fluid is Newtonian, the density is constant and uniform, therefore the flow is incompressible, and the dynamic viscosity is uniform. Considering the fluid as a continuum, the aforementioned assumptions allow us to model the flow using the Navier–Stokes equations for incompressible flow. The formulation in cylindrical coordinates is used as suggested in the text of the question.
#
# **(b)**
#
# In general, the velocity is a function of time and space, i.e.
# $$
# \vec{u} = \vec{u}(t, r, \theta, z).
# $$
# Since the flow is steady, and assumed uniform along $z$ and $\theta$ (i.e. $\partial \vec{u}/\partial \theta = 0$, $\partial \vec{u}/\partial z = 0$), the velocity also does not depend on $\theta$ and $z$. This means that the velocity must be a function of $r$ only.
#
# **(c)**
#
# The equation for mass conservation, with the assumptions of uniform velocity in $z$ and $\theta$, reduces to
#
# $$
# \frac{\partial (r u_r)}{\partial r} = 0 \quad \Rightarrow \quad \frac{d}{dr} (r u_r) = 0 \quad \Rightarrow \quad r\, u_r = C.
# $$
#
# The wall is impermeable. By applying the boundary condition $r = R \rightarrow u_r = 0$, it is found that $C = 0$. Therefore, $u_r = 0$ everywhere in the flow.
#
# **(d)**
#
# Considering the result of part (c) (i.e. $u_r = 0$) and $u_\theta = 0$ given in the question, together with the following assumptions:
#
# - (iv) steady flow,
# - (v) uniform velocity along $z$ and $\theta$,
# - (vi) uniform pressure along $\theta$,
#
# the $\theta$-component of the momentum balance reduces accordingly. The axial component of the momentum balance can be simplified as
#
# $$
# \frac{\partial u_z}{\partial t} + u_r \frac{\partial u_z}{\partial r} + \frac{u_\theta}{r} \frac{\partial u_z}{\partial \theta} + u_z \frac{\partial u_z}{\partial z} = -\frac{1}{\rho}\frac{\partial p}{\partial z} + \nu \left[\frac{1}{r} \frac{\partial}{\partial r} \left( r \frac{\partial u_z}{\partial r} \right) + \frac{1}{r^2}\frac{\partial^2 u_z}{\partial \theta^2} + \frac{\partial^2 u_z}{\partial z^2}\right] - g,
# $$
#
# leading to the following equation:
#
# $$
# 0 = \nu \frac{1}{r} \frac{d}{dr}\left( r \frac{du_z}{dr} \right) - \frac{1}{\rho}\frac{dp}{dz}\{z\, K = \text{const.}\} - g.
# \tag{1}
# $$
#
# *Expand:*
# $$
# 0 = \quad \dots
# $$
#
# *Integrate:*
# $$
# 0 = r\,\frac{d}{dr}\frac{du_z}{dr} + \frac{K r^2}{2\nu} + \frac{K r}{\nu} + C_1 \quad (*)
# $$
#
# **Boundary condition:**
# $$
# \frac{d}{dr}u_z(r)\Big|_{r=0} = 0 \quad \Rightarrow \quad C_1 = -\frac{K r^2}{2\nu} \quad (\text{with } r=0, \text{ hence } C_1 = 0).
# $$
#
# Divide by $r$:
#
# $$
# 0 = -\frac{K r}{2\nu} + \frac{du_z}{dr} + u_z + C_2.
# $$
#
# **Boundary condition:**
# $$
# u(r = R) = -U_0 \quad \Rightarrow \quad C_2 = -\frac{K R^2}{4\nu} + U_0,
# $$
#
# and hence
#
# $$
# u_z = \frac{K}{4\nu}\left(R^2 - r^2\right) - U_0.
# $$
#
# **(e)**
#
# The mass flow rate integral is written as
#
# $$
# \dot{m} = \int_0^R u_z\, 2\pi r\, dr.
# $$
#
# That is,
#
# $$
# \dot{m} = 2\pi\int_0^R \left[-\frac{K}{4\nu} r^3 + \frac{K R^2}{4\nu} r - U_0\,r\right] dr.
# $$
#
# After performing the integration (details omitted here), one obtains
#
# $$
# -\frac{K R^4}{8\nu} - U_0 R^2 = 0.
# $$
#
# Hence,
#
# $$
# K = \frac{8U_0\nu}{R^2} = -\frac{1}{\rho}\frac{dp}{dz} - g,
# $$
#
# which leads to
#
# $$
# \frac{dp}{dz} = -\rho\left(\frac{8U_0\nu}{R^2} + g\right).
# $$
#
# **(f)**
#
# *Plot:*
# (Plot not shown.)
#
# **(g)**
#
# The viscous stress tensor in cylindrical coordinates is
#
# $$
# \boldsymbol{\tau} = 2\mu \mathbf{D} =
# 2\mu
# \begin{bmatrix}
# \frac{\partial u_r}{\partial r} & \frac{1}{2}\left[\frac{\partial u_\theta}{\partial r} + \frac{1}{r}\left(\frac{\partial u_r}{\partial \theta} - u_\theta\right)\right] & \frac{1}{2}\left(\frac{\partial u_z}{\partial r} + \frac{\partial u_r}{\partial z}\right) \\
# \frac{1}{2}\left[\frac{1}{r}\left(\frac{\partial u_r}{\partial \theta} - u_\theta\right) + \frac{\partial u_\theta}{\partial r}\right] & \frac{1}{r}\left(\frac{\partial u_\theta}{\partial \theta} + u_r\right) & \frac{1}{2}\left[\frac{1}{r}\frac{\partial u_z}{\partial \theta} + \frac{\partial u_\theta}{\partial z}\right] \\
# \frac{1}{2}\left(\frac{\partial u_r}{\partial z} + \frac{\partial u_z}{\partial r}\right) & \frac{1}{2}\left[\frac{\partial u_\theta}{\partial z} + \frac{1}{r}\frac{\partial u_z}{\partial \theta}\right] & \frac{\partial u_z}{\partial z}
# \end{bmatrix}.
# $$
#
# Using the assumptions of uniform velocity along $z$ and $\theta$ and the results of parts (c) and (d), the viscous stress tensor becomes
#
# $$
# \boldsymbol{\tau} = \mu \begin{bmatrix}
# 0 & {du_z}/{dr} & 0 \\
# {du_z}/{dr} & 0 & 0 \\
# 0 & 0 & 0
# \end{bmatrix}.
# $$
#
# The expression for ${du_z}/{dr}$ comes from equation $(*)$ (with $C_1 = 0$):
#
# $$
# \frac{du_z}{dr} = \frac{K r}{2\nu}.
# $$
#
# Hence the shear stress on the fluid at $r = R$ is
#
# $$
# \tau_\text{wall} = \mu\, \frac{8U_0\nu}{R^2}\frac{R}{2\nu} = 4\mu\,\frac{U_0}{R}.
# $$
#
# **(h)**
#
# For $R = 0.02\,m$, $U_0 = 0.5\,m/s$, $L = 0.05\,m$, $\mu = 0.1\,Pa\cdot s$ (100 times water):
#
# $$
# \tau = \frac{4\mu U_0}{R} = \frac{4 \times 0.1 \times 0.5}{0.02} = 10\,Pa.
# $$
#
# The force is then calculated as
#
# $$
# F = \tau \cdot \left(2\pi R L\right) = 10 \times 2\pi \times 0.02 \times 0.05 = 0.0628\,N.
# $$
#
# This force (approximately equivalent to 628 grams) is about the weight of an adult hand. We push harder because we also charge the spring and overcome other friction in the system. The speed may be overestimated, but the viscosity may be underestimated; both affect the solution linearly.
#
# ---
#
# ## Question 2
#
# ### Flow Conditioning
#
# **(a)**
#
# **Assumptions:**
#
# - **Fluid:** Continuum, Newtonian, uniform viscosity, no body forces.
# - **Flow:** Incompressible, uniform, steady (implying laminar) flow parallel to a flat plate, two-dimensional.
# - **Limits:** $\mathrm{Re} \gg 1$ and $\delta/L \ll 1$ (note that $\partial^2 u/\partial x^2 = 0$; also note that $\partial p/\partial y = 0$ is not an assumption). Self-similarity and the condition $\partial^2 u/\partial y^2$ being dominant is a reasonable alternative.
#
# **(b)**
#
# The Blasius solution applies in this case.
#
# The displacement thickness is given by the Blasius solution as
#
# $$
# \delta_1(x = L) = 1.72\,L \sqrt{\frac{\nu}{U_0 L}} = 1.72 \sqrt{\frac{\nu L}{U_0}}.
# $$
#
# Alternative thickness measurements include the momentum thickness or the 99% thickness.
#
# The width of a wake is twice the width of one boundary layer.
#
# **(c)**
#
# The mass flow rate between two plates is
#
# $$
# \int_0^h u(x, y) \, dy.
# $$
#
# Upstream the integral yields $U_0 h$ (per unit width into the page). Downstream the mass flow must be equal and is composed of the boundary layer on either side and the bulk flow. Using the displacement thickness, the effective width reduces by $2\delta_1$, hence the central bulk velocity must increase. The mass flow rate is written as
#
# $$
# \int_0^h u(y) \, dy = U_1 (h - 2\delta_1) = U_0 h.
# $$
#
# Hence,
#
# $$
# U_1 = \frac{U_0 h}{h - 2\delta_1} = U_0 \left( 1 + \frac{2\delta_1}{h} + \dots \right),
# $$
#
# so that $U_1$ is the maximum velocity.
#
# **(d)**
#
# *Sketch:*
#
# A suggested sketch would include the length $h$ and the velocity $U_0$. (Reference may be made to $k$, $\varepsilon$, or $U'$ and the timescale $L_t/U_t$, so in this case $h/U_0$.)
#
# Students may choose a different length within reason (e.g. $2\delta$, $L$, or pipe diameter) as long as they refer to known quantities.
#
# ---
#
# ## Question 3
#
# ### Atmospheric Entry
#
# **(a)**
#
# The following assumptions are made:
#
# 1. Continuum
# 2. Inviscid
# 3. Steady
# 4. Flow along a streamline
# 5. Perfect gas
# 6. Isentropic process
# 7. No body forces
#
# One mark is given per assumption for the first five. If all seven are listed, then an additional mark is awarded.
#
# **(b)**
#
# We can use the isentropic flow relations to calculate the stagnation temperature with $M = 3.5$, $T_e = 169\,K$, and $\gamma = 1.4$:
#
# $$
# T_0 = T_e\left(1 + \frac{\gamma - 1}{2}M_e^2\right) = 169\,(1 + 0.2 \times 3.5^2) = 583\,K.
# $$
#
# **(c)**
#
# This was an open question and all answers were marked on their merit. The marking guidelines were:
#
# - Refer to an assumption (listed in part (a)).
# - Refer to a relevant dimensionless number.
# - Correctly conclude (full marks if the answer is quantitative).
# - Additional marks were available for responses that combined the above or provided a more in-depth explanation.
#
# *Example answer structure (each line is an example worth 6 marks, plus two if calculations or further discussion were given):*
#
# | Assumption     | Quantity                         | Geometry                | Conclusion                                                                                                                                         |
# |----------------|----------------------------------|-------------------------|----------------------------------------------------------------------------------------------------------------------------------------------------|
# | Continuum      | Knudsen Number                   | $\rho R T/p$            | Must be $\ll 1$.                                                                                                                                   |
# | Inviscid       | Reynolds Number                  | $\rho C_p c^2 T/k$       | May not be applicable.                                                                                                                             |
# | Steady         | $\Delta t/T$                     |                         | Must be $\gg 1$; only valid at the front but not the rear, even if Re is high.                                                                    |
# | Streamline     |                                  |                         | Quasi-steady is reasonable based on the time scale of changes relative to the timescale of interest.                                               |
# | Perfect Gas    |                                  |                         | Turbulent fluctuations are unlikely to be present on the upstream side.                                                                          |
# | Isentropic     |                                  |                         | Reasonable – or simply calculate the relevant parameter $R$. The values may differ significantly so that the relation might not be practically applicable.  |
# | Body Forces    | $\rho g h/(p_0-p_e)$             |                         | Negligible.                                                                                                                                        |
#
# *Note:* The full table and additional detailed marking comments are provided in the original exam script.
#
# ---
#
# ## Notes on the Paper
#
# ### Q1
#
# This question was designed to test the understanding and achievement of learning outcomes related to the selection of equations and their solution to solve practical problems (e.g., computation of forces). It also tested physical understanding by asking students to draw a velocity profile under well-defined constraints, select values for physical quantities, and impose boundary conditions. Overall, students performed relatively well. They demonstrated awareness of fluid mechanics equations, their selection, and use in solving a problem. Furthermore, many students showed very good physical insight when choosing numerical values for some parameters and critically commenting on the results. The main barriers to successfully completing the question were mainly related to the selection of boundary conditions and insufficient mathematical skills. More detailed comments for each part of the question are provided below.
#
# - **(a)** Almost all students selected the correct set of equations. Some mistakes were found in explaining the selection, such as missing assumptions or insufficiently formulated explanations (note: the difference between "constant" and "uniform" is crucial).
#
# - **(b)** Most students were able to use the assumptions to explain the required dependence. There were some attempts to solve the part using the continuity equation, which did not lead to the desired conclusion. Occasionally, the steady-state assumption was forgotten.
#
# - **(c)** This part was generally addressed correctly. Some issues arose with the boundary conditions (e.g., imposed at the center of the duct) and, in isolated cases, with the integration process.
#
# - **(d)** The proper equation (the $z$-component) was selected. However, many issues were found regarding the treatment of the gravitational volume force term (either the wrong direction or incorrect physical dimensions, such as missing density). There were also many issues with boundary conditions (e.g., the wrong direction for the wall velocity, inappropriate boundary condition at the center of the duct, or applying the boundary condition at $-R$). Integration mistakes (such as an incorrect integral of $1/r$) were also common.
#
# - **(e)** Several issues were noted in performing a surface integral over a circle. This was mainly due to mathematical errors. More practice with integrals in cylindrical polar coordinates is recommended.
#
# - **(f)** Many students showed some lack of understanding here. The concept of zero net mass flow rate means the axial velocity must exhibit both negative and positive components. Only a relatively limited number of students suggested a reasonable velocity profile (with both positive and negative axial components).
#
# - **(g)** Overall, students demonstrated a good understanding of the computation of forces and effectively computed the shear forces (starting from the traction vector and the definition of tensors). More clarity is needed in identifying whether the force on the fluid or the force on the wall is being computed. It should also be made clear that tensors and other quantities are computed at a specific interface.
#
# - **(h)** The answers to this question were mostly reasonable. The examiners appreciated the discussion regarding selected values and the possible sources of error. However, many answers were affected by results from previous sections that did not have the correct physical dimensions.
#
# ### Q2
#
# **(a)**
# - Few students could list all the assumptions.
# - Commonly missed were body forces, uniform flow, pressure gradient, and self-similarity.
#
# **(b)**
# - Most students used the displacement thickness, though any thickness definition was acceptable.
# - In general, performance was good; however, a significant minority did not recognize that the wake is twice the width of the boundary layer.
#
# **(c)**
# - Performance was bimodal. Almost all students who stated the principle of mass conservation received full or high marks. Other approaches generally failed.
# - This part effectively distinguished between students who knew about displacement thickness but not how to use it.
#
# **(d)**
# - Sketches indicating good intuitive understanding were common and welcomed.
# - However, few sketches indicated physically meaningful scales (e.g., the appropriate length scale).
#
# The answer to this question is elaborated in the Lecture Notes for L17 on turbulence.
# Answers that referred to kinetic energy ($k$) or the magnitude of fluctuations were given partial credit, as those quantities are unknown in this problem. For example, some students estimated $u'_{\text{RMS}}$ as 5% of $U_0$. Many students regurgitated Kolmogorov scales, which were not directly relevant (credit was given only if discussed meaningfully).
#
# Overall, Q2 worked well as an exam question. It allowed all students to demonstrate their understanding while clearly differentiating those who had studied thoroughly and gained deeper insight. The question tested various aspects, including the memorization of assumptions, basic application of those assumptions, extension to a slightly different context, sketching, and the ability to express ideas on an open-ended question (such as the final part discussing the effects of a honeycomb).
#
# Perhaps the biggest criticism of this question is that it was limited in testing engineering problem solving due to time constraints. With an extra 5–10 minutes, additional aspects (such as the drag on the honeycomb, pressure drop, optimum hole size, suppression of turbulence at the inlet, or the uniformity of the outlet flow) might have been explored.
#
# ### Q3
#
# **(a)**
# - Few students could list all the assumptions.
# - Marks were deducted for including grossly incorrect assumptions (e.g. "incompressible," "viscous," "Newtonian").
# - Note that “compressible” is not an assumption since the flow is not one-dimensional; such incorrect assumptions were usually ignored rather than penalized.
#
# **(b)**
# - Most students performed very well in this part.
# - Only a very small number either misplaced the Mach number (outside the brackets) or confused $T_0$ with $T_e$.
#
# **(c)**
# - It was essential to refer to the assumptions in the relations to comment on their applicability; this point was often lost.
# - The examiners were underwhelmed by many students’ inability to recognize that part (a) determined the applicability of part (b), and in many cases, its questionable validity.
# - To quantitatively assess the applicability of an assumption, a corresponding dimensionless number is usually needed. This was rarely, if ever, clearly expressed by the students.
# - There were also many misconceptions regarding heating on the vehicle, which is an inviscid effect due to compression. Misunderstandings about Mach number, Reynolds number, and drag or friction coefficients were common. The understanding of isentropic flow relations appeared shallow, though part (c) did highlight these limits and awarded marks where appropriate.
#
# ---
#
# This conversion preserves the original structure and ensures that all mathematical expressions are correctly formatted using Markdown’s inline ($…$) and display ($$ … $$) math modes.
#
# Extracted figures:
#   page2_img_inline: Title='', Label=''
#   page3_img_inline: Title='', Label=''

# %%
# Define the schema for the tutorial output.
class Exercise(BaseModel):
    title: str = Field(..., description="Title of the exercise (only the text, no numbering)")
    workedSolutions: list[str] = Field(..., description="List of worked solution to subquestions within the exercise (no numbering or counting)")
    
class Tutorial(BaseModel):
    name: str = Field(..., description="Title of the tutorial")
    year: str = Field(..., description="Year of the tutorial")
    exercises: list[Exercise] = Field(..., description="List of tutorial questions")

def extract_tutorial_questions(doc_page_content: str) -> dict:
    """
    Extracts the title and individual exercises from a tutorial sheet.

    This function takes the content of a tutorial sheet (doc.page_content), constructs a prompt
    instructing the LLM to infer the tutorial title and to split the text into separate questions.
    The output must be a valid JSON string with the following structure:
    
    {
        "name": "<title of tutorial>",
        "year": "<year of tutorial>",
        "exercise": [
            { title: "exercise text 1", workedSolutions: ["workedSolution text 1", "workedSolution text 2", ...] },
            { title: "exercise text 2", workedSolutions: ["workedSolution text 1", "workedSolution text 2", ...] },
            ...
        ]
    }
    
    The tutorial sheet (IMPORTED_TUTORIAL) may contain reference solutions; do not alter
    the original text of the exercises. The function returns a dictionary parsed from the JSON output.
    
    Args:
        doc_page_content (str): The content of the tutorial sheet.
        
    Returns:
        dict: A dictionary containing the keys "name" and "exercise".
              If parsing fails, returns None.
    """
    # Initialize the output parser with the Tutorial schema.
    parser = PydanticOutputParser(pydantic_object=Tutorial)

    # Construct the prompt, appending the parser's format instructions.
    prompt = f"""
        IMPORTED_TUTORIAL
        ```markdown
        {doc_page_content}
        ```

        IMPORTED_TUTORIAL is a tutorial sheet with several exercises. It may or may
        not include reference solutions. Please infer the title of the tutorial from
        the content, and extract each individual question as a separate string. Do
        not modify the text of the exercises. Only use $...$ for math expressions.

        Return a valid JSON string with the following structure:
        {parser.get_format_instructions()}
        """

    # Call the LLM
    response = llm.invoke(prompt)

    # Debug: print the raw LLM response
    print("Raw LLM Response:")
    print(response)

    try:
        # Parse the response using the output parser.
        parsed_output = parser.parse(response.content)
        # For Pydantic v2, use model_dump() to convert the model to a dictionary.
        return parsed_output.model_dump()
    except Exception as e:
        print("Error parsing LLM response as JSON:", e)
        return None

# %%
imported_tutorial = extract_tutorial_questions(doc.page_content)
# Out:
# Raw LLM Response:
# content='{\n  "name": "ME2–FMX 2023 Exam-Paper Solutions",\n  "year": "2023",\n  "exercises": [\n    {\n      "title": "Soap Dispenser",\n      "workedSolutions": [\n        " **(a)**\\n\\nThe fluid is Newtonian, the density is constant and uniform, therefore the flow is incompressible, and the dynamic viscosity is uniform. Considering the fluid as a continuum, the aforementioned assumptions allow us to model the flow using the Navier–Stokes equations for incompressible flow. The formulation in cylindrical coordinates is used as suggested in the text of the question.",\n        " **(b)**\\n\\nIn general, the velocity is a function of time and space, i.e.  $\\\\vec{u} = \\\\vec{u}(t, r, \\\\theta, z)$.  Since the flow is steady, and assumed uniform along $z$ and $\\\\theta$ (i.e. $\\\\partial \\\\vec{u}/\\\\partial \\\\theta = 0$, $\\\\partial \\\\vec{u}/\\\\partial z = 0$), the velocity also does not depend on $\\\\theta$ and $z$. This means that the velocity must be a function of $r$ only.",\n        " **(c)**\\n\\nThe equation for mass conservation, with the assumptions of uniform velocity in $z$ and $\\\\theta$, reduces to\\n\\n$\\\\frac{\\\\partial (r u_r)}{\\\\partial r} = 0 \\\\quad \\\\Rightarrow \\\\quad \\\\frac{d}{dr} (r u_r) = 0 \\\\quad \\\\Rightarrow \\\\quad r\\\\, u_r = C$.\\n\\nThe wall is impermeable. By applying the boundary condition $r = R \\\\rightarrow u_r = 0$, it is found that $C = 0$. Therefore, $u_r = 0$ everywhere in the flow.",\n        " **(d)**\\n\\nConsidering the result of part (c) (i.e. $u_r = 0$) and $u_\\\\theta = 0$ given in the question, together with the following assumptions:\\n\\n- (iv) steady flow,  \\n- (v) uniform velocity along $z$ and $\\\\theta$,  \\n- (vi) uniform pressure along $\\\\theta$,  \\n\\nthe $\\\\theta$-component of the momentum balance reduces accordingly. The axial component of the momentum balance can be simplified as\\n\\n$\\\\frac{\\\\partial u_z}{\\\\partial t} + u_r \\\\frac{\\\\partial u_z}{\\\\partial r} + \\\\frac{u_\\\\theta}{r} \\\\frac{\\\\partial u_z}{\\\\partial \\\\theta} + u_z \\\\frac{\\\\partial u_z}{\\\\partial z} = -\\\\frac{1}{\\\\rho}\\\\frac{\\\\partial p}{\\\\partial z} + \\\\nu \\\\left[\\\\frac{1}{r} \\\\frac{\\\\partial}{\\\\partial r} \\\\left( r \\\\frac{\\\\partial u_z}{\\\\partial r} \\\\right) + \\\\frac{1}{r^2}\\\\frac{\\\\partial^2 u_z}{\\\\partial \\\\theta^2} + \\\\frac{\\\\partial^2 u_z}{\\\\partial z^2}\\\\right] - g$,\\n\\nleading to the following equation:\\n\\n$0 = \\\\nu \\\\frac{1}{r} \\\\frac{d}{dr}\\\\left( r \\\\frac{du_z}{dr} \\\\right) - \\\\frac{1}{\\\\rho}\\\\frac{dp}{dz}\\\\{z\\\\, K = \\\\text{const.}\\\\} - g.$\\n\\n*Expand:*  \\n$0 = \\\\quad \\\\dots$\\n\\n*Integrate:*  \\n$0 = r\\\\,\\\\frac{d}{dr}\\\\frac{du_z}{dr} + \\\\frac{K r^2}{2\\\\nu} + \\\\frac{K r}{\\\\nu} + C_1 \\\\quad (*)$\\n\\n**Boundary condition:**  \\n$\\\\frac{d}{dr}u_z(r)\\\\Big|_{r=0} = 0 \\\\quad \\\\Rightarrow \\\\quad C_1 = -\\\\frac{K r^2}{2\\\\nu} \\\\quad (\\\\text{with } r=0, \\\\text{ hence } C_1 = 0)$.\\n\\nDivide by $r$:\\n\\n$0 = -\\\\frac{K r}{2\\\\nu} + \\\\frac{du_z}{dr} + u_z + C_2$.\\n\\n**Boundary condition:**  \\n$u(r = R) = -U_0 \\\\quad \\\\Rightarrow \\\\quad C_2 = -\\\\frac{K R^2}{4\\\\nu} + U_0$,\\n\\nand hence\\n\\n$u_z = \\\\frac{K}{4\\\\nu}\\\\left(R^2 - r^2\\\\right) - U_0$.",\n        " **(e)**\\n\\nThe mass flow rate integral is written as\\n\\n$\\\\dot{m} = \\\\int_0^R u_z\\\\, 2\\\\pi r\\\\, dr$.\\n\\nThat is,\\n\\n$\\\\dot{m} = 2\\\\pi\\\\int_0^R \\\\left[-\\\\frac{K}{4\\\\nu} r^3 + \\\\frac{K R^2}{4\\\\nu} r - U_0\\\\,r\\\\right] dr$.\\n\\nAfter performing the integration (details omitted here), one obtains\\n\\n$-\\\\frac{K R^4}{8\\\\nu} - U_0 R^2 = 0$.\\n\\nHence,\\n\\n$K = \\\\frac{8U_0\\\\nu}{R^2} = -\\\\frac{1}{\\\\rho}\\\\frac{dp}{dz} - g$,\\n\\nwhich leads to\\n\\n$\\\\frac{dp}{dz} = -\\\\rho\\\\left(\\\\frac{8U_0\\\\nu}{R^2} + g\\\\right)$.",\n        " **(f)**\\n\\n*Plot:*  \\n(Plot not shown.)",\n      ...

# %%
# Extract title
title = imported_tutorial["name"] + " " + imported_tutorial["year"]

# Print the title
print(f"Title: {title}\n")

# Extract questions
questions = imported_tutorial["exercises"]

# Loop over and print each question
for idx, question in enumerate(questions, start=1):
    print(f"**Question {idx}**:\n{question.get("title")}\n")
    print("Subquestions:")
    for subquestion in question.get("workedSolutions", []):
        print(f"- {subquestion}")
    print("-" * 40)  # Separator for readability
# Out:
# Title: ME2–FMX 2023 Exam-Paper Solutions 2023
#
# **Question 1**:
# Soap Dispenser
#
# Subquestions:
# -  **(a)**
#
# The fluid is Newtonian, the density is constant and uniform, therefore the flow is incompressible, and the dynamic viscosity is uniform. Considering the fluid as a continuum, the aforementioned assumptions allow us to model the flow using the Navier–Stokes equations for incompressible flow. The formulation in cylindrical coordinates is used as suggested in the text of the question.
# -  **(b)**
#
# In general, the velocity is a function of time and space, i.e.  $\vec{u} = \vec{u}(t, r, \theta, z)$.  Since the flow is steady, and assumed uniform along $z$ and $\theta$ (i.e. $\partial \vec{u}/\partial \theta = 0$, $\partial \vec{u}/\partial z = 0$), the velocity also does not depend on $\theta$ and $z$. This means that the velocity must be a function of $r$ only.
# -  **(c)**
#
# The equation for mass conservation, with the assumptions of uniform velocity in $z$ and $\theta$, reduces to
#
# $\frac{\partial (r u_r)}{\partial r} = 0 \quad \Rightarrow \quad \frac{d}{dr} (r u_r) = 0 \quad \Rightarrow \quad r\, u_r = C$.
#
# The wall is impermeable. By applying the boundary condition $r = R \rightarrow u_r = 0$, it is found that $C = 0$. Therefore, $u_r = 0$ everywhere in the flow.
# -  **(d)**
#
# Considering the result of part (c) (i.e. $u_r = 0$) and $u_\theta = 0$ given in the question, together with the following assumptions:
#
# - (iv) steady flow,
# - (v) uniform velocity along $z$ and $\theta$,
# - (vi) uniform pressure along $\theta$,
#
# the $\theta$-component of the momentum balance reduces accordingly. The axial component of the momentum balance can be simplified as
#
# $\frac{\partial u_z}{\partial t} + u_r \frac{\partial u_z}{\partial r} + \frac{u_\theta}{r} \frac{\partial u_z}{\partial \theta} + u_z \frac{\partial u_z}{\partial z} = -\frac{1}{\rho}\frac{\partial p}{\partial z} + \nu \left[\frac{1}{r} \frac{\partial}{\partial r} \left( r \frac{\partial u_z}{\partial r} \right) + \frac{1}{r^2}\frac{\partial^2 u_z}{\partial \theta^2} + \frac{\partial^2 u_z}{\partial z^2}\right] - g$,
#
# leading to the following equation:
#
# $0 = \nu \frac{1}{r} \frac{d}{dr}\left( r \frac{du_z}{dr} \right) - \frac{1}{\rho}\frac{dp}{dz}\{z\, K = \text{const.}\} - g.$
#
# *Expand:*
# $0 = \quad \dots$
#
# *Integrate:*
# $0 = r\,\frac{d}{dr}\frac{du_z}{dr} + \frac{K r^2}{2\nu} + \frac{K r}{\nu} + C_1 \quad (*)$
#
# **Boundary condition:**
# $\frac{d}{dr}u_z(r)\Big|_{r=0} = 0 \quad \Rightarrow \quad C_1 = -\frac{K r^2}{2\nu} \quad (\text{with } r=0, \text{ hence } C_1 = 0)$.
#
# Divide by $r$:
#
# $0 = -\frac{K r}{2\nu} + \frac{du_z}{dr} + u_z + C_2$.
#
# **Boundary condition:**
# $u(r = R) = -U_0 \quad \Rightarrow \quad C_2 = -\frac{K R^2}{4\nu} + U_0$,
#
# and hence
#
# $u_z = \frac{K}{4\nu}\left(R^2 - r^2\right) - U_0$.
# -  **(e)**
#
# The mass flow rate integral is written as
#
# $\dot{m} = \int_0^R u_z\, 2\pi r\, dr$.
#
# That is,
#
# $\dot{m} = 2\pi\int_0^R \left[-\frac{K}{4\nu} r^3 + \frac{K R^2}{4\nu} r - U_0\,r\right] dr$.
#
# After performing the integration (details omitted here), one obtains
#
# $-\frac{K R^4}{8\nu} - U_0 R^2 = 0$.
#
# Hence,
#
# $K = \frac{8U_0\nu}{R^2} = -\frac{1}{\rho}\frac{dp}{dz} - g$,
#
# which leads to
#
# $\frac{dp}{dz} = -\rho\left(\frac{8U_0\nu}{R^2} + g\right)$.
# -  **(f)**
#
# *Plot:*
# (Plot not shown.)
# -  **(g)**
#
# The viscous stress tensor in cylindrical coordinates is
#
# $\boldsymbol{\tau} = 2\mu \mathbf{D} =
# 2\mu
# \begin{bmatrix}
# \frac{\partial u_r}{\partial r} & \frac{1}{2}\left[\frac{\partial u_\theta}{\partial r} + \frac{1}{r}\left(\frac{\partial u_r}{\partial \theta} - u_\theta\right)\right] & \frac{1}{2}\left(\frac{\partial u_z}{\partial r} + \frac{\partial u_r}{\partial z}\right) \\
# \frac{1}{2}\left[\frac{1}{r}\left(\frac{\partial u_r}{\partial \theta} - u_\theta\right) + \frac{\partial u_\theta}{\partial r}\right] & \frac{1}{r}\left(\frac{\partial u_\theta}{\partial \theta} + u_r\right) & \frac{1}{2}\left[\frac{1}{r}\frac{\partial u_z}{\partial \theta} + \frac{\partial u_\theta}{\partial z}\right] \\
# \frac{1}{2}\left(\frac{\partial u_r}{\partial z} + \frac{\partial u_z}{\partial r}\right) & \frac{1}{2}\left[\frac{\partial u_\theta}{\partial z} + \frac{1}{r}\frac{\partial u_z}{\partial \theta}\right] & \frac{\partial u_z}{\partial z}
# \end{bmatrix}.$
#
# Using the assumptions of uniform velocity along $z$ and $\theta$ and the results of parts (c) and (d), the viscous stress tensor becomes
#
# $\boldsymbol{\tau} = \mu \begin{bmatrix}
# 0 & {du_z}/{dr} & 0 \\
# {du_z}/{dr} & 0 & 0 \\
# 0 & 0 & 0
# \end{bmatrix}.$
#
# The expression for ${du_z}/{dr}$ comes from equation $(*)$ (with $C_1 = 0$):
#
# $\frac{du_z}{dr} = \frac{K r}{2\nu}$.
#
# Hence the shear stress on the fluid at $r = R$ is
#
# $\tau_\text{wall} = \mu\, \frac{8U_0\nu}{R^2}\frac{R}{2\nu} = 4\mu\,\frac{U_0}{R}$.
# -  **(h)**
#
# For $R = 0.02\,m$, $U_0 = 0.5\,m/s$, $L = 0.05\,m$, $\mu = 0.1\,Pa\cdot s$ (100 times water):
#
# $\tau = \frac{4\mu U_0}{R} = \frac{4 \times 0.1 \times 0.5}{0.02} = 10\,Pa$.
#
# The force is then calculated as
#
# $F = \tau \cdot \left(2\pi R L\right) = 10 \times 2\pi \times 0.02 \times 0.05 = 0.0628\,N$.
#
# This force (approximately equivalent to 628 grams) is about the weight of an adult hand. We push harder because we also charge the spring and overcome other friction in the system. The speed may be overestimated, but the viscosity may be underestimated; both affect the solution linearly.
# ----------------------------------------
# **Question 2**:
# Flow Conditioning
#
# Subquestions:
# -  **(a)**
#
# **Assumptions:**
#
# - **Fluid:** Continuum, Newtonian, uniform viscosity, no body forces.
# - **Flow:** Incompressible, uniform, steady (implying laminar) flow parallel to a flat plate, two-dimensional.
# - **Limits:** $\mathrm{Re} \gg 1$ and $\delta/L \ll 1$ (note that $\partial^2 u/\partial x^2 = 0$; also note that $\partial p/\partial y = 0$ is not an assumption). Self-similarity and the condition $\partial^2 u/\partial y^2$ being dominant is a reasonable alternative.
# -  **(b)**
#
# The Blasius solution applies in this case.
#
# The displacement thickness is given by the Blasius solution as
#
# $\delta_1(x = L) = 1.72\,L \sqrt{\frac{\nu}{U_0 L}} = 1.72 \sqrt{\frac{\nu L}{U_0}}$.
#
# Alternative thickness measurements include the momentum thickness or the 99% thickness.
#
# The width of a wake is twice the width of one boundary layer.
# -  **(c)**
#
# The mass flow rate between two plates is
#
# $\int_0^h u(x, y) \; dy$.
#
# Upstream the integral yields $U_0 h$ (per unit width into the page). Downstream the mass flow must be equal and is composed of the boundary layer on either side and the bulk flow. Using the displacement thickness, the effective width reduces by $2\delta_1$, hence the central bulk velocity must increase. The mass flow rate is written as
#
# $\int_0^h u(y) \; dy = U_1 (h - 2\delta_1) = U_0 h$.
#
# Hence,
#
# $U_1 = \frac{U_0 h}{h - 2\delta_1} = U_0 \left( 1 + \frac{2\delta_1}{h} + \dots \right)$,
#
# so that $U_1$ is the maximum velocity.
# -  **(d)**
#
# *Sketch:*
#
# A suggested sketch would include the length $h$ and the velocity $U_0$. (Reference may be made to $k$, $\varepsilon$, or $U'$ and the timescale $L_t/U_t$, so in this case $h/U_0$.)
#
# Students may choose a different length within reason (e.g. $2\delta$, $L$, or pipe diameter) as long as they refer to known quantities.
# ----------------------------------------
# **Question 3**:
# Atmospheric Entry
#
# Subquestions:
# -  **(a)**
#
# The following assumptions are made:
#
# 1. Continuum
# 2. Inviscid
# 3. Steady
# 4. Flow along a streamline
# 5. Perfect gas
# 6. Isentropic process
# 7. No body forces
#
# One mark is given per assumption for the first five. If all seven are listed, then an additional mark is awarded.
# -  **(b)**
#
# We can use the isentropic flow relations to calculate the stagnation temperature with $M = 3.5$, $T_e = 169\,K$, and $\gamma = 1.4$:
#
# $T_0 = T_e\left(1 + \frac{\gamma - 1}{2}M_e^2\right) = 169\,(1 + 0.2 \times 3.5^2) = 583\,K$.
# -  **(c)**
#
# This was an open question and all answers were marked on their merit. The marking guidelines were:
#
# - Refer to an assumption (listed in part (a)).
# - Refer to a relevant dimensionless number.
# - Correctly conclude (full marks if the answer is quantitative).
# - Additional marks were available for responses that combined the above or provided a more in-depth explanation.
#
# *Example answer structure (each line is an example worth 6 marks, plus two if calculations or further discussion were given):*
#
# | Assumption     | Quantity                         | Geometry                | Conclusion                                                                                                                                         |
# |----------------|----------------------------------|-------------------------|----------------------------------------------------------------------------------------------------------------------------------------------------|
# | Continuum      | Knudsen Number                   | $\rho R T/p$            | Must be $\ll 1$.                                                                                                                                   |
# | Inviscid       | Reynolds Number                  | $\rho C_p c^2 T/k$       | May not be applicable.                                                                                                                             |
# | Steady         | $\Delta t/T$                     |                         | Must be $\gg 1$; only valid at the front but not the rear, even if Re is high.                                                                    |
# | Streamline     |                                  |                         | Quasi-steady is reasonable based on the time scale of changes relative to the timescale of interest.                                               |
# | Perfect Gas    |                                  |                         | Turbulent fluctuations are unlikely to be present on the upstream side.                                                                          |
# | Isentropic     |                                  |                         | Reasonable – or simply calculate the relevant parameter $R$. The values may differ significantly so that the relation might not be practically applicable.  |
# | Body Forces    | $\rho g h/(p_0-p_e)$             |                         | Negligible.
#
# *Note:* The full table and additional detailed marking comments are provided in the original exam script.
# ----------------------------------------

# %%
# Define the nested Pydantic models based on the JSON schema.

class Part(BaseModel):
    answer: str = Field(..., description="Part answer text")
    content: str = Field(..., description="Part content text")
    orderNumber: int = Field(..., description="The order number of this part")

class QuestionJson(BaseModel):
    orderNumber: int = Field(..., description="The order number of the question")
    parts: list[Part] = Field(..., description="List of question parts")
    title: str = Field(..., description="Question title")

def create_question_json(question: str) -> dict:
    # Initialize the output parser using the defined Pydantic model.
    parser = PydanticOutputParser(pydantic_object=QuestionJson)

    # Minimum JSON template to guide the model. (Used as context.)
    minimum_json_template = r'''{
      "orderNumber": 0,
      "parts": [
        {
          "answer": "",
          "content": "Part text here",
          "orderNumber": 0,
        }
      ],
      "title": "Question title here"
    }'''

    # Construct the prompt, appending the parser's format instructions.
    question_prompt = f'''
      JSON_TEMPLATE
      ```json
      {minimum_json_template}
      ```

      IMPORTED_QUESTION
      ```markdown
      {question}
      ```

      If you see something like "HII 5\u201310 mins\n\n", drop it from the text. Preserve the Katex
      math formatting. Do not modify the original text of the question.

      From the content of each part, infer the final answer and store it in the "answer" field.

      Carefully map IMPORTED_QUESTION into the JSON_TEMPLATE and return valid JSON.

      {parser.get_format_instructions()}
      '''

    # Invoke the language model.
    response = llm.invoke(question_prompt)

    try:
        # Parse the response using the output parser.
        parsed_output = parser.parse(response.content)
        return parsed_output.model_dump()  # Return as a dictionary.
    except Exception as e:
        print("Error parsing JSON from LLM response:", e)
        print("LLM response:", response.content)
        return None

# %%
from pydantic import BaseModel, Field
from langchain.output_parsers import PydanticOutputParser

# Define a Pydantic model representing the expected output schema.
class QuestionName(BaseModel):
    question_name: str = Field(..., description="A short tag representing the question’s topic.")

def create_question_name(question: str) -> str:
    # Initialize the output parser with the schema.
    parser = PydanticOutputParser(pydantic_object=QuestionName)

    # Build a prompt that includes the parser's format instructions.
    question_name_prompt = f'''
      IMPORTED_QUESTION
      ```markdown
      {question}
      ```
      
      QUERY:
      Based on the above markdown content, infer a suitable short name tag that represents the question’s topic.
      Follow these rules:
      
        1. Look for the heading text (for example, if the text starts with "Question 1:" followed by "Hydraulic scale", then the main topic is "Hydraulic scale").
        2. Normalize the name by replacing spaces with underscores and removing punctuation.
        3. Return only a valid JSON object with a single property "question_name".
      
      {parser.get_format_instructions()}
    '''
    # Invoke the language model.
    response = llm.invoke(question_name_prompt)

    try:
        # Parse the response using the output parser.
        parsed_output = parser.parse(response.content)
        return parsed_output.question_name
    except Exception as e:
        print("Error parsing JSON from LLM response:", e)
        print("LLM response:", response.content)
        return None

# %%
def create_tutorial_metadata(tutorial_title: str) -> dict:
    """
    Args:
        tutorial_title (str): The full tutorial title.

    Returns:
        str: name of the tutorial.
    """
    # Generate a short name for the tutorial (could name fancier using LLM).
    # - convert to lower-case,
    # - replace spaces with underscores,
    # - remove any characters except letters, numbers, underscores, and hyphens.
    normalized_name = tutorial_title.lower()  # convert to lower-case
    normalized_name = re.sub(r'\s+', '_', normalized_name)         # replace spaces with underscores
    normalized_name = re.sub(r'[^a-z0-9_-]', '', normalized_name)   # remove other characters
    tutorial_normalized_title = normalized_name
    
    return tutorial_normalized_title

tutorial_title = imported_tutorial["name"] + " " + imported_tutorial["year"]
tutorial_normalized_title = create_tutorial_metadata(tutorial_title)

set_filename = f"ans_{tutorial_normalized_title}.json"
set_filepath = set_filename.split(".")[0]
print(f"Set filename: {set_filename}, set filepath: {set_filepath}")
# Out:
# Set filename: ans_me2fmx_2023_exam-paper_solutions_2023.json, set filepath: ans_me2fmx_2023_exam-paper_solutions_2023

# %%
# Loop over and print each question
for idx, question in enumerate(questions, start=1):
    print(f"**Question {idx}**:\n{question}\n")

    print("INFO: Mapping question in markdown into JSON")
    question_json = create_question_json(question)
    question_json["orderNumber"] = idx-1
    print(f"INFO: JSON {idx}:\n{question_json}\n")
    
    print("INFO: Get question name.")
    question_name = create_question_name(question)

    if f"{set_filepath}" not in os.listdir("pastpapers/json/"):
        os.mkdir(f"pastpapers/json/{set_filepath}")
    
    question_index = f"{(idx-1):03}" 
    filename = f"pastpapers/json/{set_filepath}/question_{question_index}_{question_name}.json"
    print(f"INFO: writing {filename}")
    open(filename, "w").write(json.dumps(question_json, indent=2))
    
    # break # breaking here as just doing quick test
# Out:
# **Question 1**:
# {'title': 'Soap Dispenser', 'workedSolutions': [' **(a)**\n\nThe fluid is Newtonian, the density is constant and uniform, therefore the flow is incompressible, and the dynamic viscosity is uniform. Considering the fluid as a continuum, the aforementioned assumptions allow us to model the flow using the Navier–Stokes equations for incompressible flow. The formulation in cylindrical coordinates is used as suggested in the text of the question.', ' **(b)**\n\nIn general, the velocity is a function of time and space, i.e.  $\\vec{u} = \\vec{u}(t, r, \\theta, z)$.  Since the flow is steady, and assumed uniform along $z$ and $\\theta$ (i.e. $\\partial \\vec{u}/\\partial \\theta = 0$, $\\partial \\vec{u}/\\partial z = 0$), the velocity also does not depend on $\\theta$ and $z$. This means that the velocity must be a function of $r$ only.', ' **(c)**\n\nThe equation for mass conservation, with the assumptions of uniform velocity in $z$ and $\\theta$, reduces to\n\n$\\frac{\\partial (r u_r)}{\\partial r} = 0 \\quad \\Rightarrow \\quad \\frac{d}{dr} (r u_r) = 0 \\quad \\Rightarrow \\quad r\\, u_r = C$.\n\nThe wall is impermeable. By applying the boundary condition $r = R \\rightarrow u_r = 0$, it is found that $C = 0$. Therefore, $u_r = 0$ everywhere in the flow.', ' **(d)**\n\nConsidering the result of part (c) (i.e. $u_r = 0$) and $u_\\theta = 0$ given in the question, together with the following assumptions:\n\n- (iv) steady flow,  \n- (v) uniform velocity along $z$ and $\\theta$,  \n- (vi) uniform pressure along $\\theta$,  \n\nthe $\\theta$-component of the momentum balance reduces accordingly. The axial component of the momentum balance can be simplified as\n\n$\\frac{\\partial u_z}{\\partial t} + u_r \\frac{\\partial u_z}{\\partial r} + \\frac{u_\\theta}{r} \\frac{\\partial u_z}{\\partial \\theta} + u_z \\frac{\\partial u_z}{\\partial z} = -\\frac{1}{\\rho}\\frac{\\partial p}{\\partial z} + \\nu \\left[\\frac{1}{r} \\frac{\\partial}{\\partial r} \\left( r \\frac{\\partial u_z}{\\partial r} \\right) + \\frac{1}{r^2}\\frac{\\partial^2 u_z}{\\partial \\theta^2} + \\frac{\\partial^2 u_z}{\\partial z^2}\\right] - g$,\n\nleading to the following equation:\n\n$0 = \\nu \\frac{1}{r} \\frac{d}{dr}\\left( r \\frac{du_z}{dr} \\right) - \\frac{1}{\\rho}\\frac{dp}{dz}\\{z\\, K = \\text{const.}\\} - g.$\n\n*Expand:*  \n$0 = \\quad \\dots$\n\n*Integrate:*  \n$0 = r\\,\\frac{d}{dr}\\frac{du_z}{dr} + \\frac{K r^2}{2\\nu} + \\frac{K r}{\\nu} + C_1 \\quad (*)$\n\n**Boundary condition:**  \n$\\frac{d}{dr}u_z(r)\\Big|_{r=0} = 0 \\quad \\Rightarrow \\quad C_1 = -\\frac{K r^2}{2\\nu} \\quad (\\text{with } r=0, \\text{ hence } C_1 = 0)$.\n\nDivide by $r$:\n\n$0 = -\\frac{K r}{2\\nu} + \\frac{du_z}{dr} + u_z + C_2$.\n\n**Boundary condition:**  \n$u(r = R) = -U_0 \\quad \\Rightarrow \\quad C_2 = -\\frac{K R^2}{4\\nu} + U_0$,\n\nand hence\n\n$u_z = \\frac{K}{4\\nu}\\left(R^2 - r^2\\right) - U_0$.', ' **(e)**\n\nThe mass flow rate integral is written as\n\n$\\dot{m} = \\int_0^R u_z\\, 2\\pi r\\, dr$.\n\nThat is,\n\n$\\dot{m} = 2\\pi\\int_0^R \\left[-\\frac{K}{4\\nu} r^3 + \\frac{K R^2}{4\\nu} r - U_0\\,r\\right] dr$.\n\nAfter performing the integration (details omitted here), one obtains\n\n$-\\frac{K R^4}{8\\nu} - U_0 R^2 = 0$.\n\nHence,\n\n$K = \\frac{8U_0\\nu}{R^2} = -\\frac{1}{\\rho}\\frac{dp}{dz} - g$,\n\nwhich leads to\n\n$\\frac{dp}{dz} = -\\rho\\left(\\frac{8U_0\\nu}{R^2} + g\\right)$.', ' **(f)**\n\n*Plot:*  \n(Plot not shown.)', ' **(g)**\n\nThe viscous stress tensor in cylindrical coordinates is\n\n$\\boldsymbol{\\tau} = 2\\mu \\mathbf{D} =\n2\\mu\n\\begin{bmatrix}\n\\frac{\\partial u_r}{\\partial r} & \\frac{1}{2}\\left[\\frac{\\partial u_\\theta}{\\partial r} + \\frac{1}{r}\\left(\\frac{\\partial u_r}{\\partial \\theta} - u_\\theta\\right)\\right] & \\frac{1}{2}\\left(\\frac{\\partial u_z}{\\partial r} + \\frac{\\partial u_r}{\\partial z}\\right) \\\\\n\\frac{1}{2}\\left[\\frac{1}{r}\\left(\\frac{\\partial u_r}{\\partial \\theta} - u_\\theta\\r ...
#
# INFO: Mapping question in markdown into JSON
# INFO: JSON 1:
# {'orderNumber': 0, 'parts': [{'answer': 'The fluid is Newtonian with constant and uniform density and viscosity, which allows us to model the incompressible flow using the Navier–Stokes equations in cylindrical coordinates.', 'content': 'Part text here', 'orderNumber': 0}, {'answer': 'Since the flow is steady and uniform along both $z$ and $\\theta$, the velocity can only be a function of $r$.', 'content': 'Part text here', 'orderNumber': 1}, {'answer': 'By applying mass conservation and the impermeable wall boundary condition, it is found that $u_r = 0$ everywhere in the flow.', 'content': 'Part text here', 'orderNumber': 2}, {'answer': 'The integration of the momentum balance (with $C_1 = 0$) leads to the result: $u_z = \\frac{K}{4\\nu}\\left(R^2 - r^2\\right) - U_0$.', 'content': 'Part text here', 'orderNumber': 3}, {'answer': 'The mass flow rate integration yields the pressure gradient: $\\frac{dp}{dz} = -\\rho\\left(\\frac{8U_0\\nu}{R^2} + g\\right)$.', 'content': 'Part text here', 'orderNumber': 4}, {'answer': 'Plot not shown.', 'content': 'Part text here', 'orderNumber': 5}, {'answer': 'Using the simplified viscous stress tensor and $\\frac{du_z}{dr} = \\frac{K\\,r}{2\\nu}$, the shear stress on the wall is found to be $\\tau_{\\text{wall}} = \\frac{4\\mu U_0}{R}$.', 'content': 'Part text here', 'orderNumber': 6}, {'answer': 'For $R = 0.02\\,m$, $U_0 = 0.5\\,m/s$, $L = 0.05\\,m$, and $\\mu = 0.1\\,Pa\\cdot s$, the shear stress evaluates to $10\\,Pa$, yielding a force of $F \\approx 0.0628\\,N$, which is roughly equivalent to the weight of an adult hand.', 'content': 'Part text here', 'orderNumber': 7}], 'title': 'Soap Dispenser'}
#
# INFO: Get question name.
# INFO: writing pastpapers/json/ans_me2fmx_2023_exam-paper_solutions_2023/question_000_Soap_Dispenser.json
# **Question 2**:
# {'title': 'Flow Conditioning', 'workedSolutions': [' **(a)**\n\n**Assumptions:**\n\n- **Fluid:** Continuum, Newtonian, uniform viscosity, no body forces.\n- **Flow:** Incompressible, uniform, steady (implying laminar) flow parallel to a flat plate, two-dimensional.\n- **Limits:** $\\mathrm{Re} \\gg 1$ and $\\delta/L \\ll 1$ (note that $\\partial^2 u/\\partial x^2 = 0$; also note that $\\partial p/\\partial y = 0$ is not an assumption). Self-similarity and the condition $\\partial^2 u/\\partial y^2$ being dominant is a reasonable alternative.', ' **(b)**\n\nThe Blasius solution applies in this case.\n\nThe displacement thickness is given by the Blasius solution as\n\n$\\delta_1(x = L) = 1.72\\,L \\sqrt{\\frac{\\nu}{U_0 L}} = 1.72 \\sqrt{\\frac{\\nu L}{U_0}}$.\n\nAlternative thickness measurements include the momentum thickness or the 99% thickness.\n\nThe width of a wake is twice the width of one boundary layer.', ' **(c)**\n\nThe mass flow rate between two plates is\n\n$\\int_0^h u(x, y) \\; dy$.\n\nUpstream the integral yields $U_0 h$ (per unit width into the page). Downstream the mass flow must be equal and is composed of the boundary layer on either side and the bulk flow. Using the displacement thickness, the effective width reduces by $2\\delta_1$, hence the central bulk velocity must increase. The mass flow rate is written as\n\n$\\int_0^h u(y) \\; dy = U_1 (h - 2\\delta_1) = U_0 h$.\n\nHence,\n\n$U_1 = \\frac{U_0 h}{h - 2\\delta_1} = U_0 \\left( 1 + \\frac{2\\delta_1}{h} + \\dots \\right)$, \n\nso that $U_1$ is the maximum velocity.', " **(d)**\n\n*Sketch:*\n\nA suggested sketch would include the length $h$ and the velocity $U_0$. (Reference may be made to $k$, $\\varepsilon$, or $U'$ and the timescale $L_t/U_t$, so in this case $h/U_0$.)\n\nStudents may choose a different length within reason (e.g. $2\\delta$, $L$, or pipe diameter) as long as they refer to known quantities."]}
#
# INFO: Mapping question in markdown into JSON
# INFO: JSON 2:
# {'orderNumber': 1, 'parts': [{'answer': 'The final answer for part (a) is that the analysis assumes a continuum, Newtonian fluid of uniform viscosity with incompressible, steady, and two‐dimensional flow parallel to a flat plate. In addition, it is assumed that $\\mathrm{Re} \\gg 1$ and $\\delta/L \\ll 1$, so that the streamwise second derivative of velocity can be neglected in favor of the dominant $\\partial^2 u/\\partial y^2$ term.', 'content': ' **(a)**\n\n**Assumptions:**\n\n- **Fluid:** Continuum, Newtonian, uniform viscosity, no body forces.\n- **Flow:** Incompressible, uniform, steady (implying laminar) flow parallel to a flat plate, two-dimensional.\n- **Limits:** $\\mathrm{Re} \\gg 1$ and $\\delta/L \\ll 1$ (note that $\\partial^2 u/\\partial x^2 = 0$; also note that $\\partial p/\\partial y = 0$ is not an assumption). Self-similarity and the condition $\\partial^2 u/\\partial y^2$ being dominant is a reasonable alternative.', 'orderNumber': 0}, {'answer': 'The final answer for part (b) is that the displacement thickness is given by $\\delta_1(x=L)=1.72\\sqrt{\\frac{\\nu L}{U_0}}$ as obtained from the Blasius solution, and the wake width is twice the thickness of one boundary layer.', 'content': ' **(b)**\n\nThe Blasius solution applies in this case.\n\nThe displacement thickness is given by the Blasius solution as\n\n$\\delta_1(x = L) = 1.72\\,L \\sqrt{\\frac{\\nu}{U_0 L}} = 1.72 \\sqrt{\\frac{\\nu L}{U_0}}$.\n\nAlternative thickness measurements include the momentum thickness or the 99% thickness.\n\nThe width of a wake is twice the width of one boundary layer.', 'orderNumber': 1}, {'answer': 'The final answer for part (c) is that mass conservation yields the maximum (central) velocity as $U_1 = \\frac{U_0 h}{h - 2\\delta_1}$, which can be expanded as $U_1 = U_0 \\left( 1 + \\frac{2\\delta_1}{h} + \\dots \\right)$.', 'content': ' **(c)**\n\nThe mass flow rate between two plates is\n\n$\\int_0^h u(x, y) \\; dy$.\n\nUpstream the integral yields $U_0 h$ (per unit width into the page). Downstream the mass flow must be equal and is composed of the boundary layer on either side and the bulk flow. Using the displacement thickness, the effective width reduces by $2\\delta_1$, hence the central bulk velocity must increase. The mass flow rate is written as\n\n$\\int_0^h u(y) \\; dy = U_1 (h - 2\\delta_1) = U_0 h$.\n\nHence,\n\n$U_1 = \\frac{U_0 h}{h - 2\\delta_1} = U_0 \\left( 1 + \\frac{2\\delta_1}{h} + \\dots \\right)$, \n\nso that $U_1$ is the maximum velocity.', 'orderNumber': 2}, {'answer': 'The final answer for part (d) is a sketch that clearly labels the channel height $h$ and the uniform velocity $U_0$, with the understanding that other related parameters (such as $k$, $\\varepsilon$, or a characteristic timescale $h/U_0$) may also be indicated depending on the chosen reference length.', 'content': " **(d)**\n\n*Sketch:*\n\nA suggested sketch would include the length $h$ and the velocity $U_0$. (Reference may be made to $k$, $\\varepsilon$, or $U'$ and the timescale $L_t/U_t$, so in this case $h/U_0$.)\n\nStudents may choose a different length within reason (e.g. $2\\delta$, $L$, or pipe diameter) as long as they refer to known quantities.", 'orderNumber': 3}], 'title': 'Flow Conditioning'}
#
# INFO: Get question name.
# INFO: writing pastpapers/json/ans_me2fmx_2023_exam-paper_solutions_2023/question_001_Flow_Conditioning.json
# **Question 3**:
# {'title': 'Atmospheric Entry', 'workedSolutions': [' **(a)**\n\nThe following assumptions are made:\n\n1. Continuum  \n2. Inviscid  \n3. Steady  \n4. Flow along a streamline  \n5. Perfect gas  \n6. Isentropic process  \n7. No body forces  \n\nOne mark is given per assumption for the first five. If all seven are listed, then an additional mark is awarded.', ' **(b)**\n\nWe can use the isentropic flow relations to calculate the stagnation temperature with $M = 3.5$, $T_e = 169\\,K$, and $\\gamma = 1.4$:\n\n$T_0 = T_e\\left(1 + \\frac{\\gamma - 1}{2}M_e^2\\right) = 169\\,(1 + 0.2 \\times 3.5^2) = 583\\,K$.', ' **(c)**\n\nThis was an open question and all answers were marked on their merit. The marking guidelines were:\n\n- Refer to an assumption (listed in part (a)).\n- Refer to a relevant dimensionless number.\n- Correctly conclude (full marks if the answer is quantitative).\n- Additional marks were available for responses that combined the above or provided a more in-depth explanation.\n\n*Example answer structure (each line is an example worth 6 marks, plus two if calculations or further discussion were given):*\n\n| Assumption     | Quantity                         | Geometry                | Conclusion                                                                                                                                         |\n|----------------|----------------------------------|-------------------------|----------------------------------------------------------------------------------------------------------------------------------------------------|\n| Continuum      | Knudsen Number                   | $\\rho R T/p$            | Must be $\\ll 1$.                                                                                                                                   |\n| Inviscid       | Reynolds Number                  | $\\rho C_p c^2 T/k$       | May not be applicable.                                                                                                                             |\n| Steady         | $\\Delta t/T$                     |                         | Must be $\\gg 1$; only valid at the front but not the rear, even if Re is high.                                                                    |\n| Streamline     |                                  |                         | Quasi-steady is reasonable based on the time scale of changes relative to the timescale of interest.                                               |\n| Perfect Gas    |                                  |                         | Turbulent fluctuations are unlikely to be present on the upstream side.                                                                          |\n| Isentropic     |                                  |                         | Reasonable – or simply calculate the relevant parameter $R$. The values may differ significantly so that the relation might not be practically applicable.  |\n| Body Forces    | $\\rho g h/(p_0-p_e)$             |                         | Negligible.\n\n*Note:* The full table and additional detailed marking comments are provided in the original exam script.']}
#
# INFO: Mapping question in markdown into JSON
# INFO: JSON 3:
# {'orderNumber': 2, 'parts': [{'answer': 'Final answer: The candidate should list the seven assumptions – Continuum, Inviscid, Steady, Flow along a streamline, Perfect gas, Isentropic process, and No body forces. One mark is awarded for each of the first five assumptions, with an extra mark if all seven are provided.', 'content': ' **(a)**\n\nThe following assumptions are made:\n\n1. Continuum  \n2. Inviscid  \n3. Steady  \n4. Flow along a streamline  \n5. Perfect gas  \n6. Isentropic process  \n7. No body forces  \n\nOne mark is given per assumption for the first five. If all seven are listed, then an additional mark is awarded.', 'orderNumber': 0}, {'answer': 'Final answer: Using the isentropic flow relations with M = 3.5, Tₑ = 169 K, and γ = 1.4, the stagnation temperature is calculated as T₀ = 583 K.', 'content': ' **(b)**\n\nWe can use the isentropic flow relations to calculate the stagnation temperature with $M = 3.5$, $T_e = 169\\,K$, and $\\gamma = 1.4$:\n\n$T_0 = T_e\\left(1 + \\frac{\\gamma - 1}{2}M_e^2\\right) = 169\\,(1 + 0.2 \\times 3.5^2) = 583\\,K$.', 'orderNumber': 1}, {'answer': 'Final answer: Marks are awarded based on the merit of each answer, with points given for mentioning a relevant assumption (from part a), citing an appropriate dimensionless number, and drawing the correct quantitative or qualitative conclusion. Additional marks are available for responses that combine these elements or provide further explanation.', 'content': ' **(c)**\n\nThis was an open question and all answers were marked on their merit. The marking guidelines were:\n\n- Refer to an assumption (listed in part (a)).\n- Refer to a relevant dimensionless number.\n- Correctly conclude (full marks if the answer is quantitative).\n- Additional marks were available for responses that combined the above or provided a more in-depth explanation.\n\n*Example answer structure (each line is an example worth 6 marks, plus two if calculations or further discussion were given):*\n\n| Assumption     | Quantity                         | Geometry                | Conclusion                                                                                                                                         |\n|----------------|----------------------------------|-------------------------|----------------------------------------------------------------------------------------------------------------------------------------------------|\n| Continuum      | Knudsen Number                   | $\\rho R T/p$            | Must be $\\ll 1$.                                                                                                                                   |\n| Inviscid       | Reynolds Number                  | $\\rho C_p c^2 T/k$       | May not be applicable.                                                                                                                             |\n| Steady         | $\\Delta t/T$                     |                         | Must be $\\gg 1$; only valid at the front but not the rear, even if Re is high.                                                                    |\n| Streamline     |                                  |                         | Quasi-steady is reasonable based on the time scale of changes relative to the timescale of interest.                                               |\n| Perfect Gas    |                                  |                         | Turbulent fluctuations are unlikely to be present on the upstream side.                                                                          |\n| Isentropic     |                                  |                         | Reasonable – or simply calculate the relevant parameter $R$. The values may differ significantly so that the relation might not be practically applicable.  |\n| Body Forces    | $\\rho g h/(p_0-p_e)$             |                         | Negligible.\n\n*Note:* The full table and additional detailed marking c ...
#
# INFO: Get question name.
# INFO: writing pastpapers/json/ans_me2fmx_2023_exam-paper_solutions_2023/question_002_Atmospheric_Entry.json

# %%
# MERGE ANSWERS INTO QUESTIONS
# Loop over and print each question
for idx, question in enumerate(questions, start=1):
    print(f"**Question {idx}**:\n{question}\n")

    # read the JSON file
    question_index = f"{(idx-1):03}" 
    print("INFO: Get question name.")
    question_name = create_question_name(question)
  
    ans_filename = f"pastpapers/json/{set_filepath}/question_{question_index}_{question_name}.json"
    print(f"INFO: reading {ans_filename}")
    ans_json = json.loads(open(ans_filename).read())

    # in the set_fluid_mechanics_{year} folder, find the file with same question_{question_index}_{question_name}.json name
    q_filename = f"pastpapers/json/set_fluid_mechanics_{imported_tutorial['year']}/question_{question_index}_{question_name}.json"
    question_json = json.loads(open(q_filename).read())

    # find the part with the same orderNumber in both json files under parts
    for part in question_json["parts"]:
        for ans_part in ans_json["parts"]:
            if part["orderNumber"] == ans_part["orderNumber"]:
                # merge the workedSolution into the question
                print(f"INFO: ans_workedSolution: {ans_part['content']}")
                part["workedSolution"]["content"] = ans_part["content"]
                print(f"INFO:orderNumber {part['orderNumber']} matched, merged workedSolution: {part['workedSolution']}")
                break
        else:
            # If no match was found, set workedSolution to None
            part["workedSolution"] = None

    print(f"INFO: JSON {idx}:\n{str(question_json)}\n")

    # SAVE TO NEW JSON FILE
    combined_set_filepath = f"set_fluid_mechanics_{imported_tutorial['year']}"
    if f"{combined_set_filepath}" not in os.listdir("pastpapers/json_combined/"):
        os.mkdir(f"pastpapers/json_combined/{combined_set_filepath}")
    
    question_index = f"{(idx-1):03}" 
    filename = f"pastpapers/json_combined/{combined_set_filepath}/question_{question_index}_{question_name}.json"
    print(f"INFO: writing {filename}")
    open(filename, "w").write(json.dumps(question_json, indent=2))
# Out:
# **Question 1**:
# {'title': 'Soap Dispenser', 'workedSolutions': [' **(a)**\n\nThe fluid is Newtonian, the density is constant and uniform, therefore the flow is incompressible, and the dynamic viscosity is uniform. Considering the fluid as a continuum, the aforementioned assumptions allow us to model the flow using the Navier–Stokes equations for incompressible flow. The formulation in cylindrical coordinates is used as suggested in the text of the question.', ' **(b)**\n\nIn general, the velocity is a function of time and space, i.e.  $\\vec{u} = \\vec{u}(t, r, \\theta, z)$.  Since the flow is steady, and assumed uniform along $z$ and $\\theta$ (i.e. $\\partial \\vec{u}/\\partial \\theta = 0$, $\\partial \\vec{u}/\\partial z = 0$), the velocity also does not depend on $\\theta$ and $z$. This means that the velocity must be a function of $r$ only.', ' **(c)**\n\nThe equation for mass conservation, with the assumptions of uniform velocity in $z$ and $\\theta$, reduces to\n\n$\\frac{\\partial (r u_r)}{\\partial r} = 0 \\quad \\Rightarrow \\quad \\frac{d}{dr} (r u_r) = 0 \\quad \\Rightarrow \\quad r\\, u_r = C$.\n\nThe wall is impermeable. By applying the boundary condition $r = R \\rightarrow u_r = 0$, it is found that $C = 0$. Therefore, $u_r = 0$ everywhere in the flow.', ' **(d)**\n\nConsidering the result of part (c) (i.e. $u_r = 0$) and $u_\\theta = 0$ given in the question, together with the following assumptions:\n\n- (iv) steady flow,  \n- (v) uniform velocity along $z$ and $\\theta$,  \n- (vi) uniform pressure along $\\theta$,  \n\nthe $\\theta$-component of the momentum balance reduces accordingly. The axial component of the momentum balance can be simplified as\n\n$\\frac{\\partial u_z}{\\partial t} + u_r \\frac{\\partial u_z}{\\partial r} + \\frac{u_\\theta}{r} \\frac{\\partial u_z}{\\partial \\theta} + u_z \\frac{\\partial u_z}{\\partial z} = -\\frac{1}{\\rho}\\frac{\\partial p}{\\partial z} + \\nu \\left[\\frac{1}{r} \\frac{\\partial}{\\partial r} \\left( r \\frac{\\partial u_z}{\\partial r} \\right) + \\frac{1}{r^2}\\frac{\\partial^2 u_z}{\\partial \\theta^2} + \\frac{\\partial^2 u_z}{\\partial z^2}\\right] - g$,\n\nleading to the following equation:\n\n$0 = \\nu \\frac{1}{r} \\frac{d}{dr}\\left( r \\frac{du_z}{dr} \\right) - \\frac{1}{\\rho}\\frac{dp}{dz}\\{z\\, K = \\text{const.}\\} - g.$\n\n*Expand:*  \n$0 = \\quad \\dots$\n\n*Integrate:*  \n$0 = r\\,\\frac{d}{dr}\\frac{du_z}{dr} + \\frac{K r^2}{2\\nu} + \\frac{K r}{\\nu} + C_1 \\quad (*)$\n\n**Boundary condition:**  \n$\\frac{d}{dr}u_z(r)\\Big|_{r=0} = 0 \\quad \\Rightarrow \\quad C_1 = -\\frac{K r^2}{2\\nu} \\quad (\\text{with } r=0, \\text{ hence } C_1 = 0)$.\n\nDivide by $r$:\n\n$0 = -\\frac{K r}{2\\nu} + \\frac{du_z}{dr} + u_z + C_2$.\n\n**Boundary condition:**  \n$u(r = R) = -U_0 \\quad \\Rightarrow \\quad C_2 = -\\frac{K R^2}{4\\nu} + U_0$,\n\nand hence\n\n$u_z = \\frac{K}{4\\nu}\\left(R^2 - r^2\\right) - U_0$.', ' **(e)**\n\nThe mass flow rate integral is written as\n\n$\\dot{m} = \\int_0^R u_z\\, 2\\pi r\\, dr$.\n\nThat is,\n\n$\\dot{m} = 2\\pi\\int_0^R \\left[-\\frac{K}{4\\nu} r^3 + \\frac{K R^2}{4\\nu} r - U_0\\,r\\right] dr$.\n\nAfter performing the integration (details omitted here), one obtains\n\n$-\\frac{K R^4}{8\\nu} - U_0 R^2 = 0$.\n\nHence,\n\n$K = \\frac{8U_0\\nu}{R^2} = -\\frac{1}{\\rho}\\frac{dp}{dz} - g$,\n\nwhich leads to\n\n$\\frac{dp}{dz} = -\\rho\\left(\\frac{8U_0\\nu}{R^2} + g\\right)$.', ' **(f)**\n\n*Plot:*  \n(Plot not shown.)', ' **(g)**\n\nThe viscous stress tensor in cylindrical coordinates is\n\n$\\boldsymbol{\\tau} = 2\\mu \\mathbf{D} =\n2\\mu\n\\begin{bmatrix}\n\\frac{\\partial u_r}{\\partial r} & \\frac{1}{2}\\left[\\frac{\\partial u_\\theta}{\\partial r} + \\frac{1}{r}\\left(\\frac{\\partial u_r}{\\partial \\theta} - u_\\theta\\right)\\right] & \\frac{1}{2}\\left(\\frac{\\partial u_z}{\\partial r} + \\frac{\\partial u_r}{\\partial z}\\right) \\\\\n\\frac{1}{2}\\left[\\frac{1}{r}\\left(\\frac{\\partial u_r}{\\partial \\theta} - u_\\theta\\r ...
#
# INFO: Get question name.
# INFO: reading pastpapers/json/ans_me2fmx_2023_exam-paper_solutions_2023/question_000_Soap_Dispenser.json
# INFO: ans_workedSolution: The fluid is Newtonian, the density is constant and uniform; therefore the flow is incompressible, and the dynamic viscosity is uniform. Considering the fluid as a continuum, the aforementioned assumptions allow us to model the flow using the Navier–Stokes equations for incompressible flow. The formulation in cylindrical coordinates is used as suggested in the text of the question.
# INFO:orderNumber 0 matched, merged workedSolution: {'content': 'The fluid is Newtonian, the density is constant and uniform; therefore the flow is incompressible, and the dynamic viscosity is uniform. Considering the fluid as a continuum, the aforementioned assumptions allow us to model the flow using the Navier–Stokes equations for incompressible flow. The formulation in cylindrical coordinates is used as suggested in the text of the question.', 'id': 'N/A', 'title': '', 'children': []}
# INFO: ans_workedSolution: In general, the velocity is a function of time and space, i.e.
#
# $\vec{u} = \vec{u}(t, r, \theta, z)$.
#
# Since the flow is steady, and assumed uniform along $z$ and $\theta$ (i.e.
#
# $\frac{\partial \vec{u}}{\partial \theta} = 0,\quad \frac{\partial \vec{u}}{\partial z} = 0)$,
#
# the velocity also does not depend on $\theta$ and $z$. This means that the velocity must be a function of $r$ only.
# INFO:orderNumber 1 matched, merged workedSolution: {'content': 'In general, the velocity is a function of time and space, i.e. \n \n$\\vec{u} = \\vec{u}(t, r, \\theta, z)$. \n\nSince the flow is steady, and assumed uniform along $z$ and $\\theta$ (i.e. \n \n$\\frac{\\partial \\vec{u}}{\\partial \\theta} = 0,\\quad \\frac{\\partial \\vec{u}}{\\partial z} = 0)$, \n\nthe velocity also does not depend on $\\theta$ and $z$. This means that the velocity must be a function of $r$ only.', 'id': 'N/A', 'title': '', 'children': []}
# INFO: ans_workedSolution: The equation for mass conservation, with the assumptions of uniform velocity in $z$ and $\theta$, reduces to
#
# $\frac{1}{r}\frac{\partial (r u_r)}{\partial r} = 0 \quad\Longrightarrow\quad \frac{d}{dr}(r u_r) = 0 \quad\Longrightarrow\quad r\, u_r = C$.
#
# The wall is impermeable. By applying the boundary condition $r=R \Rightarrow u_r=0$, it is found that $C=0$. Therefore,
#
# $u_r = 0$
#
# everywhere in the flow.
# INFO:orderNumber 2 matched, merged workedSolution: {'content': 'The equation for mass conservation, with the assumptions of uniform velocity in $z$ and $\\theta$, reduces to\n \n$\\frac{1}{r}\\frac{\\partial (r u_r)}{\\partial r} = 0 \\quad\\Longrightarrow\\quad \\frac{d}{dr}(r u_r) = 0 \\quad\\Longrightarrow\\quad r\\, u_r = C$. \n\nThe wall is impermeable. By applying the boundary condition $r=R \\Rightarrow u_r=0$, it is found that $C=0$. Therefore, \n \n$u_r = 0$ \n\neverywhere in the flow.', 'id': 'N/A', 'title': '', 'children': []}
# INFO: ans_workedSolution: Considering the result of part (c), i.e. $u_r = 0$, and given that $u_\theta = 0$ (as stated in the question), together with the assumptions of
# - (iv) steady flow,
# - (v) uniform velocity along $z$ and $\theta$, and
# - (vi) uniform pressure along $\theta$,
#
# the $\theta$-component of the momentum balance reduces to a simplified form. The axial component of the momentum balance can be simplified as follows. With the assumptions:
#
# - (iv) steady flow,
# - (v) uniform velocity along $z$ and $\theta$,
# - (vi) uniform pressure along $\theta$,
#
# the full equation
#
# $\frac{\partial u_z}{\partial t} + 0\; u_r\frac{\partial u_z}{\partial r} + 0\; u_\theta\frac{\partial u_z}{\partial \theta} + u_z\frac{\partial u_z}{\partial z} = -\frac{1}{\rho}\frac{\partial p}{\partial z} + \nu\left[\frac{1}{r}\frac{\partial}{\partial r}\left(r\frac{\partial u_z}{\partial r}\right) + \frac{1}{r^2}\frac{\partial^2 u_z}{\partial \theta^2} + \frac{\partial^2 u_z}{\partial z^2}\right] - g,$
#
# graduces (after neglecting the time derivative and the convective terms that vanish under the assumptions) to
#
# $0 = \nu\frac{1}{r}\frac{d}{dr}\left( r\frac{d u_z}{dr}\right) + \frac{1}{\rho}\frac{dp}{dz} - g$.
#
# *Expand:*
# The expanded form (after multiplying by $r$ and reordering terms) is
#
# $0 = \nu\,\frac{d}{dr}\left( r\,\frac{du_z}{dr}\right) + r\left[\frac{1}{\rho}\frac{dp}{dz} - g\right]$.
#
# *Integrate:*
# Integrating (with respect to $r$) yields an expression of the form
#
# $0 = r\frac{d u_z}{dr} + \frac{K\,r^2}{2\nu} + C_1$,
#
# where $K$ is related to the pressure gradient via
#
# $K = -\left(\frac{dp}{dz}\frac{1}{\rho} + g\right)$.
#
# *Boundary condition:*
# Using the boundary condition
#
# $\left.\frac{du_z}{dr}\right|_{r=0} = 0$,
#
# one finds that $C_1 = -\displaystyle\frac{K\,R^2}{2\nu}$. (Note: For $r=0$, $C_1=0$ is also implied by symmetry.) Dividing by $r$ (for $r>0$) and integrating one obtains
#
# $\frac{du_z}{dr} = -\frac{K\,r}{2\nu} + \frac{C_2}{r}$.
#
# Then, imposing the boundary condition
#
# $u_z(r=R) = -U_0$,
#
# one ultimately finds
#
# $u_z = \frac{K}{4\nu}\Bigl(R^2 - r^2\Bigr) - U_0$.
# INFO:orderNumber 3 matched, merged workedSolution: {'content': 'Considering the result of part (c), i.e. $u_r = 0$, and given that $u_\\theta = 0$ (as stated in the question), together with the assumptions of  \n- (iv) steady flow,  \n- (v) uniform velocity along $z$ and $\\theta$, and  \n- (vi) uniform pressure along $\\theta$,  \n\nthe $\\theta$-component of the momentum balance reduces to a simplified form. The axial component of the momentum balance can be simplified as follows. With the assumptions:\n \n- (iv) steady flow,  \n- (v) uniform velocity along $z$ and $\\theta$,  \n- (vi) uniform pressure along $\\theta$,  \n\nthe full equation\n \n$\\frac{\\partial u_z}{\\partial t} + 0\\; u_r\\frac{\\partial u_z}{\\partial r} + 0\\; u_\\theta\\frac{\\partial u_z}{\\partial \\theta} + u_z\\frac{\\partial u_z}{\\partial z} = -\\frac{1}{\\rho}\\frac{\\partial p}{\\partial z} + \\nu\\left[\\frac{1}{r}\\frac{\\partial}{\\partial r}\\left(r\\frac{\\partial u_z}{\\partial r}\\right) + \\frac{1}{r^2}\\frac{\\partial^2 u_z}{\\partial \\theta^2} + \\frac{\\partial^2 u_z}{\\partial z^2}\\right] - g,$ \n\ngraduces (after neglecting the time derivative and the convective terms that vanish under the assumptions) to\n \n$0 = \\nu\\frac{1}{r}\\frac{d}{dr}\\left( r\\frac{d u_z}{dr}\\right) + \\frac{1}{\\rho}\\frac{dp}{dz} - g$. \n\n*Expand:*  \nThe expanded form (after multiplying by $r$ and reordering terms) is\n \n$0 = \\nu\\,\\frac{d}{dr}\\left( r\\,\\frac{du_z}{dr}\\right) + r\\left[\\frac{1}{\\rho}\\frac{dp}{dz} - g\\right]$. \n\n*Integrate:*  \nIntegrating (with respect to $r$) yields an expression of the form\n \n$0 = r\\frac{d u_z}{dr} + \\frac{K\\,r^2}{2\\nu} + C_1$, \n\nwhere $K$ is related to the pressure gradient via\n \n$K = -\\left(\\frac{dp}{dz}\\frac{1}{\\rho} + g\\right)$. \n\n*Boundary condition:*  \nUsing the boundary condition\n \n$\\left.\\frac{du_z}{dr}\\right|_{r=0} = 0$, \n\none finds that $C_1 = -\\displaystyle\\frac{K\\,R^2}{2\\nu}$. (Note: For $r=0$, $C_1=0$ is also implied by symmetry.) Dividing by $r$ (for $r>0$) and integrating one obtains\n \n$\\frac{du_z}{dr} = -\\frac{K\\,r}{2\\nu} + \\frac{C_2}{r}$. \n\nThen, imposing the boundary condition\n \n$u_z(r=R) = -U_0$, \n\none ultimately finds\n \n$u_z = \\frac{K}{4\\nu}\\Bigl(R^2 - r^2\\Bigr) - U_0$.', 'id': 'N/A', 'title': '', 'children': []}
# INFO: ans_workedSolution: The mass flow rate integral is written as
#
# $\dot{m} = \int_0^R u_z\, 2\pi r\, dr$.
#
# Substituting the expression for $u_z$, the integral becomes
#
# $\dot{m} = 2\pi\int_0^R \left[-\frac{K}{4\nu}r^3 + \frac{K\, R^2}{4\nu}r - U_0\,r\right]dr$.
#
# After performing the integration one obtains
#
# $-\frac{K R^4}{8\nu} - U_0\frac{R^2}{2} = 0$.
#
# Hence,
#
# $K = \frac{8U_0\nu}{R^2} \quad\text{and} \quad K = -\left(\frac{1}{\rho}\frac{dp}{dz} + g\right)$.
#
# Thus, the pressure gradient obtained is
#
# $\frac{dp}{dz} = -\rho\left(\frac{8U_0\nu}{R^2} + g\right)$.
# INFO:orderNumber 4 matched, merged workedSolution: {'content': 'The mass flow rate integral is written as\n \n$\\dot{m} = \\int_0^R u_z\\, 2\\pi r\\, dr$. \n\nSubstituting the expression for $u_z$, the integral becomes\n \n$\\dot{m} = 2\\pi\\int_0^R \\left[-\\frac{K}{4\\nu}r^3 + \\frac{K\\, R^2}{4\\nu}r - U_0\\,r\\right]dr$. \n\nAfter performing the integration one obtains\n \n$-\\frac{K R^4}{8\\nu} - U_0\\frac{R^2}{2} = 0$. \n\nHence,\n \n$K = \\frac{8U_0\\nu}{R^2} \\quad\\text{and} \\quad K = -\\left(\\frac{1}{\\rho}\\frac{dp}{dz} + g\\right)$. \n\nThus, the pressure gradient obtained is\n \n$\\frac{dp}{dz} = -\\rho\\left(\\frac{8U_0\\nu}{R^2} + g\\right)$.', 'id': 'N/A', 'title': '', 'children': []}
# INFO: ans_workedSolution: *Plot:*
#
# ![pictureTag](question_000_soap_dispenser_0002.png)
# INFO:orderNumber 5 matched, merged workedSolution: {'content': '*Plot:* \n\n![pictureTag](question_000_soap_dispenser_0002.png)', 'id': 'N/A', 'title': '', 'children': []}
# INFO: ans_workedSolution: The viscous stress tensor in cylindrical coordinates is given by
#
# $\boldsymbol{\tau} = 2\mu\,\mathbf{D} =
# 2\mu \begin{bmatrix}
# \displaystyle \frac{\partial u_r}{\partial r} & \displaystyle \frac{1}{2}\left[\frac{\partial u_\theta}{\partial r} + \frac{1}{r}\left(\frac{\partial u_r}{\partial \theta} - u_\theta\right)\right] & \displaystyle \frac{1}{2}\left(\frac{\partial u_z}{\partial r} + \frac{\partial u_r}{\partial z}\right) \\[1.2em]
# \displaystyle \frac{1}{2}\left[\frac{1}{r}\left(\frac{\partial u_r}{\partial \theta} - u_\theta\right) + \frac{\partial u_\theta}{\partial r}\right] & \displaystyle \frac{1}{r}\left(\frac{\partial u_\theta}{\partial \theta} + u_r\right) & \displaystyle \frac{1}{2}\left[\frac{1}{r}\frac{\partial u_z}{\partial \theta} + \frac{\partial u_\theta}{\partial z}\right] \\[1.2em]
# \displaystyle \frac{1}{2}\left(\frac{\partial u_r}{\partial z} + \frac{\partial u_z}{\partial r}\right) & \displaystyle \frac{1}{2}\left[\frac{\partial u_\theta}{\partial z} + \frac{1}{r}\frac{\partial u_z}{\partial \theta}\right] & \displaystyle \frac{\partial u_z}{\partial z}
# \end{bmatrix}. $
#
# Using the assumptions of uniform velocity along $z$ and $\theta$ and the results of parts (c) and (d), the viscous stress tensor simplifies to
#
# $\boldsymbol{\tau} = \mu \begin{bmatrix}
# 0 & \dfrac{du_z}{dr} & 0 \\m]
# \dfrac{du_z}{dr} & 0 & 0 \\m]
# 0 & 0 & 0
# \end{bmatrix}. $
#
# The expression for $\dfrac{du_z}{dr}$ comes from the previous integration (with $C_1 = 0$):
#
# $\frac{du_z}{dr} = \frac{K\, r}{2\nu}$.
#
# Hence the shear stress on the fluid at $r=R$ is
#
# $\tau_{\text{wall}} = \mu\,\frac{K\, R}{2\nu} = \frac{4\mu\, U_0}{R}$,
#
# where we have used $K = \displaystyle \frac{8U_0\nu}{R^2}$.
# INFO:orderNumber 6 matched, merged workedSolution: {'content': 'The viscous stress tensor in cylindrical coordinates is given by\n \n$\\boldsymbol{\\tau} = 2\\mu\\,\\mathbf{D} =\n2\\mu \\begin{bmatrix}\n\\displaystyle \\frac{\\partial u_r}{\\partial r} & \\displaystyle \\frac{1}{2}\\left[\\frac{\\partial u_\\theta}{\\partial r} + \\frac{1}{r}\\left(\\frac{\\partial u_r}{\\partial \\theta} - u_\\theta\\right)\\right] & \\displaystyle \\frac{1}{2}\\left(\\frac{\\partial u_z}{\\partial r} + \\frac{\\partial u_r}{\\partial z}\\right) \\\\[1.2em]\n\\displaystyle \\frac{1}{2}\\left[\\frac{1}{r}\\left(\\frac{\\partial u_r}{\\partial \\theta} - u_\\theta\\right) + \\frac{\\partial u_\\theta}{\\partial r}\\right] & \\displaystyle \\frac{1}{r}\\left(\\frac{\\partial u_\\theta}{\\partial \\theta} + u_r\\right) & \\displaystyle \\frac{1}{2}\\left[\\frac{1}{r}\\frac{\\partial u_z}{\\partial \\theta} + \\frac{\\partial u_\\theta}{\\partial z}\\right] \\\\[1.2em]\n\\displaystyle \\frac{1}{2}\\left(\\frac{\\partial u_r}{\\partial z} + \\frac{\\partial u_z}{\\partial r}\\right) & \\displaystyle \\frac{1}{2}\\left[\\frac{\\partial u_\\theta}{\\partial z} + \\frac{1}{r}\\frac{\\partial u_z}{\\partial \\theta}\\right] & \\displaystyle \\frac{\\partial u_z}{\\partial z}\n\\end{bmatrix}. $\n\nUsing the assumptions of uniform velocity along $z$ and $\\theta$ and the results of parts (c) and (d), the viscous stress tensor simplifies to\n \n$\\boldsymbol{\\tau} = \\mu \\begin{bmatrix}\n0 & \\dfrac{du_z}{dr} & 0 \\\\m]\n\\dfrac{du_z}{dr} & 0 & 0 \\\\m]\n0 & 0 & 0\n\\end{bmatrix}. $\n\nThe expression for $\\dfrac{du_z}{dr}$ comes from the previous integration (with $C_1 = 0$):\n \n$\\frac{du_z}{dr} = \\frac{K\\, r}{2\\nu}$. \n\nHence the shear stress on the fluid at $r=R$ is\n \n$\\tau_{\\text{wall}} = \\mu\\,\\frac{K\\, R}{2\\nu} = \\frac{4\\mu\\, U_0}{R}$, \n\nwhere we have used $K = \\displaystyle \\frac{8U_0\\nu}{R^2}$.', 'id': 'N/A', 'title': '', 'children': []}
# INFO: ans_workedSolution: For
# - $R = 0.02\, \mathrm{m}$,
# - $U_0 = 0.5\, \mathrm{m/s}$,
# - $L = 0.05\, \mathrm{m}$, and
# - $\mu = 0.1\, \mathrm{Pa\cdot s}$ (100 times that of water):
#
# First, the stress is
#
# $\tau = \frac{4\mu\, U_0}{R} = \frac{4\cdot 0.1\cdot 0.5}{0.02} = 10\, \mathrm{Pa}$.
#
# Then, the force is
#
# $F = \tau \cdot (2\pi R L) = 10\cdot (2\pi\cdot 0.02\cdot 0.05) \approx 0.0628\, \mathrm{N}$.
#
# This force (about 628 grams in weight) is comparable to the weight of an adult hand. In practice, we push harder because we also charge the spring and overcome other sources of friction in the system. The speed may be overestimated, but the viscosity may be underestimated; both affect the solution linearly.
# INFO:orderNumber 7 matched, merged workedSolution: {'content': 'For  \n- $R = 0.02\\, \\mathrm{m}$,  \n- $U_0 = 0.5\\, \\mathrm{m/s}$,  \n- $L = 0.05\\, \\mathrm{m}$, and  \n- $\\mu = 0.1\\, \\mathrm{Pa\\cdot s}$ (100 times that of water):\n\nFirst, the stress is\n \n$\\tau = \\frac{4\\mu\\, U_0}{R} = \\frac{4\\cdot 0.1\\cdot 0.5}{0.02} = 10\\, \\mathrm{Pa}$. \n\nThen, the force is\n \n$F = \\tau \\cdot (2\\pi R L) = 10\\cdot (2\\pi\\cdot 0.02\\cdot 0.05) \\approx 0.0628\\, \\mathrm{N}$. \n\nThis force (about 628 grams in weight) is comparable to the weight of an adult hand. In practice, we push harder because we also charge the spring and overcome other sources of friction in the system. The speed may be overestimated, but the viscosity may be underestimated; both affect the solution linearly.', 'id': 'N/A', 'title': '', 'children': []}
# INFO: JSON 1:
# {'orderNumber': 0, 'displayFinalAnswer': True, 'displayStructuredTutorial': True, 'displayWorkedSolution': True, 'masterContent': 'A soap dispenser uses a hand-driven pump. The tube labelled ($14$) in **Figure Q1** is flooded with soap. The tube is pushed downwards against a spring and soap leaves through the top opening of the tube. You are required to estimate the resistance that the soap exerts on the tube ($14$) as the tube is depressed.\n\nUse the cylindrical coordinate system in **Figure Q1**, where the origin is fixed in space. You may make the following assumptions:\n- The tube is moving steadily downwards at a speed $U_0$ relative to the origin.\n- The tube is not rotating.\n- The flow is steady, with no azimuthal velocity component ($u_\\theta = 0$).\n- The fluid velocity is uniform in the axial direction, $z$, and in the azimuthal direction, $\\theta$.\n- The fluid is Newtonian with density, $\\rho$, and dynamic viscosity, $\\mu$, both constant and uniform.\n- The axial pressure gradient, $\\frac{\\partial p}{\\partial z}$, is constant.\n\n![pictureTag](question_000_soap_dispenser_0001.png)\n\n**Figure Q1** – Left: schematic of a soap dispenser. Right: the tube ($14$) in detail.', 'parts': [{'answerContent': '', 'content': 'Which set of equations would you use to study the flow in the tube and why?', 'orderNumber': 0, 'responseAreas': [], 'tutorial': [], 'universalPartId': 'N/A', 'workedSolution': {'content': 'The fluid is Newtonian, the density is constant and uniform; therefore the flow is incompressible, and the dynamic viscosity is uniform. Considering the fluid as a continuum, the aforementioned assumptions allow us to model the flow using the Navier–Stokes equations for incompressible flow. The formulation in cylindrical coordinates is used as suggested in the text of the question.', 'id': 'N/A', 'title': '', 'children': []}}, {'answerContent': '', 'content': 'Using the given assumptions, explain why the velocity of the fluid in the tube is a _function of the radial coordinate, $r$, only.', 'orderNumber': 1, 'responseAreas': [], 'tutorial': [], 'universalPartId': 'N/A', 'workedSolution': {'content': 'In general, the velocity is a function of time and space, i.e. \n \n$\\vec{u} = \\vec{u}(t, r, \\theta, z)$. \n\nSince the flow is steady, and assumed uniform along $z$ and $\\theta$ (i.e. \n \n$\\frac{\\partial \\vec{u}}{\\partial \\theta} = 0,\\quad \\frac{\\partial \\vec{u}}{\\partial z} = 0)$, \n\nthe velocity also does not depend on $\\theta$ and $z$. This means that the velocity must be a function of $r$ only.', 'id': 'N/A', 'title': '', 'children': []}}, {'answerContent': '', 'content': 'Show that the $r$-component of the velocity is zero everywhere in the tube.', 'orderNumber': 2, 'responseAreas': [], 'tutorial': [], 'universalPartId': 'N/A', 'workedSolution': {'content': 'The equation for mass conservation, with the assumptions of uniform velocity in $z$ and $\\theta$, reduces to\n \n$\\frac{1}{r}\\frac{\\partial (r u_r)}{\\partial r} = 0 \\quad\\Longrightarrow\\quad \\frac{d}{dr}(r u_r) = 0 \\quad\\Longrightarrow\\quad r\\, u_r = C$. \n\nThe wall is impermeable. By applying the boundary condition $r=R \\Rightarrow u_r=0$, it is found that $C=0$. Therefore, \n \n$u_r = 0$ \n\neverywhere in the flow.', 'id': 'N/A', 'title': '', 'children': []}}, {'answerContent': '', 'content': 'Derive an expression for the $z$-component of the velocity in the tube, $u_z = u_z(r)$, in terms of $U_0$, $R$, $\\frac{\\partial p}{\\partial z}$, $\\rho$, $\\mu$, $g$, where $g$ is acceleration due to gravity and $R$ is the tube inner radius.', 'orderNumber': 3, 'responseAreas': [], 'tutorial': [], 'universalPartId': 'N/A', 'workedSolution': {'content': 'Considering the result of part (c), i.e. $u_r = 0$, and given that $u_\\theta = 0$ (as stated in the question), together with the assumptions of  \n- (iv) steady flow,  \n- (v) uniform velocity along $z$ and $\\theta$, and  \n- (vi) uniform pressure along $\\theta$,  \n\nthe $\\t ...
#
# INFO: writing pastpapers/json_combined/set_fluid_mechanics_2023/question_000_Soap_Dispenser.json
# **Question 2**:
# {'title': 'Flow Conditioning', 'workedSolutions': [' **(a)**\n\n**Assumptions:**\n\n- **Fluid:** Continuum, Newtonian, uniform viscosity, no body forces.\n- **Flow:** Incompressible, uniform, steady (implying laminar) flow parallel to a flat plate, two-dimensional.\n- **Limits:** $\\mathrm{Re} \\gg 1$ and $\\delta/L \\ll 1$ (note that $\\partial^2 u/\\partial x^2 = 0$; also note that $\\partial p/\\partial y = 0$ is not an assumption). Self-similarity and the condition $\\partial^2 u/\\partial y^2$ being dominant is a reasonable alternative.', ' **(b)**\n\nThe Blasius solution applies in this case.\n\nThe displacement thickness is given by the Blasius solution as\n\n$\\delta_1(x = L) = 1.72\\,L \\sqrt{\\frac{\\nu}{U_0 L}} = 1.72 \\sqrt{\\frac{\\nu L}{U_0}}$.\n\nAlternative thickness measurements include the momentum thickness or the 99% thickness.\n\nThe width of a wake is twice the width of one boundary layer.', ' **(c)**\n\nThe mass flow rate between two plates is\n\n$\\int_0^h u(x, y) \\; dy$.\n\nUpstream the integral yields $U_0 h$ (per unit width into the page). Downstream the mass flow must be equal and is composed of the boundary layer on either side and the bulk flow. Using the displacement thickness, the effective width reduces by $2\\delta_1$, hence the central bulk velocity must increase. The mass flow rate is written as\n\n$\\int_0^h u(y) \\; dy = U_1 (h - 2\\delta_1) = U_0 h$.\n\nHence,\n\n$U_1 = \\frac{U_0 h}{h - 2\\delta_1} = U_0 \\left( 1 + \\frac{2\\delta_1}{h} + \\dots \\right)$, \n\nso that $U_1$ is the maximum velocity.', " **(d)**\n\n*Sketch:*\n\nA suggested sketch would include the length $h$ and the velocity $U_0$. (Reference may be made to $k$, $\\varepsilon$, or $U'$ and the timescale $L_t/U_t$, so in this case $h/U_0$.)\n\nStudents may choose a different length within reason (e.g. $2\\delta$, $L$, or pipe diameter) as long as they refer to known quantities."]}
#
# INFO: Get question name.
# INFO: reading pastpapers/json/ans_me2fmx_2023_exam-paper_solutions_2023/question_001_Flow_Conditioning.json
# INFO: ans_workedSolution: **Assumptions:**
#
# - **Fluid:** Continuum, Newtonian, uniform viscosity, no body forces.
# - **Flow:** Incompressible, uniform, steady (implying laminar) flow parallel to a flat plate, two-dimensional.
# - **Limits:** $\mathrm{Re} \gg 1$ and $\delta/L \ll 1$ (note that $\partial^2 u/\partial x^2 = 0$; also note that $\partial p/\partial y = 0$ is not an assumption). Self-similarity and the condition $\partial^2 u/\partial y^2$ being dominant is a reasonable alternative.
# INFO:orderNumber 0 matched, merged workedSolution: {'content': '**Assumptions:**\n\n- **Fluid:** Continuum, Newtonian, uniform viscosity, no body forces.\n- **Flow:** Incompressible, uniform, steady (implying laminar) flow parallel to a flat plate, two-dimensional.\n- **Limits:** $\\mathrm{Re} \\gg 1$ and $\\delta/L \\ll 1$ (note that $\\partial^2 u/\\partial x^2 = 0$; also note that $\\partial p/\\partial y = 0$ is not an assumption). Self-similarity and the condition $\\partial^2 u/\\partial y^2$ being dominant is a reasonable alternative.', 'id': 'N/A', 'title': '', 'children': []}
# INFO: ans_workedSolution: The Blasius solution applies in this case.
#
# The displacement thickness is given by the Blasius solution as
#
# $\delta_1(x = L) = 1.72\,L \sqrt{\frac{\nu}{U_0 L}} = 1.72 \sqrt{\frac{\nu L}{U_0}}$.
#
# Alternative thickness measurements include the momentum thickness or the 99% thickness.
#
# The width of a wake is twice the width of one boundary layer.
# INFO:orderNumber 1 matched, merged workedSolution: {'content': 'The Blasius solution applies in this case.\n\nThe displacement thickness is given by the Blasius solution as\n\n$\\delta_1(x = L) = 1.72\\,L \\sqrt{\\frac{\\nu}{U_0 L}} = 1.72 \\sqrt{\\frac{\\nu L}{U_0}}$.\n\nAlternative thickness measurements include the momentum thickness or the 99% thickness.\n\nThe width of a wake is twice the width of one boundary layer.', 'id': 'N/A', 'title': '', 'children': []}
# INFO: ans_workedSolution: The mass flow rate between two plates is
#
# $\int_0^h u(x, y) \; dy$.
#
# Upstream the integral yields $U_0 h$ (per unit width into the page). Downstream the mass flow must be equal and is composed of the boundary layer on either side and the bulk flow. Using the displacement thickness, the effective width reduces by $2\delta_1$, hence the central bulk velocity must increase. The mass flow rate is written as
#
# $\int_0^h u(y) \; dy = U_1 (h - 2\delta_1) = U_0 h$.
#
# Hence,
#
# $U_1 = \frac{U_0 h}{h - 2\delta_1} = U_0 \left( 1 + \frac{2\delta_1}{h} + \dots \right)$,
#
# so that $U_1$ is the maximum velocity.
# INFO:orderNumber 2 matched, merged workedSolution: {'content': 'The mass flow rate between two plates is\n\n$\\int_0^h u(x, y) \\; dy$.\n\nUpstream the integral yields $U_0 h$ (per unit width into the page). Downstream the mass flow must be equal and is composed of the boundary layer on either side and the bulk flow. Using the displacement thickness, the effective width reduces by $2\\delta_1$, hence the central bulk velocity must increase. The mass flow rate is written as\n\n$\\int_0^h u(y) \\; dy = U_1 (h - 2\\delta_1) = U_0 h$.\n\nHence,\n\n$U_1 = \\frac{U_0 h}{h - 2\\delta_1} = U_0 \\left( 1 + \\frac{2\\delta_1}{h} + \\dots \\right)$, \n\nso that $U_1$ is the maximum velocity.', 'id': 'N/A', 'title': '', 'children': []}
# INFO: ans_workedSolution: *Sketch:*
#
# ![pictureTag](question_001_Flow_Conditioning_0002.png)
#
# A suggested sketch would include the length $h$ and the velocity $U_0$. (Reference may be made to $k$, $\varepsilon$, or $U'$ and the timescale $L_t/U_t$, so in this case $h/U_0$.)
#
# Students may choose a different length within reason (e.g. $2\delta$, $L$, or pipe diameter) as long as they refer to known quantities.
# INFO:orderNumber 3 matched, merged workedSolution: {'content': "*Sketch:*\n\n![pictureTag](question_001_Flow_Conditioning_0002.png)\n\nA suggested sketch would include the length $h$ and the velocity $U_0$. (Reference may be made to $k$, $\\varepsilon$, or $U'$ and the timescale $L_t/U_t$, so in this case $h/U_0$.)\n\nStudents may choose a different length within reason (e.g. $2\\delta$, $L$, or pipe diameter) as long as they refer to known quantities.", 'id': 'N/A', 'title': '', 'children': []}
# INFO: JSON 2:
# {'orderNumber': 1, 'displayFinalAnswer': True, 'displayStructuredTutorial': True, 'displayWorkedSolution': True, 'masterContent': 'Honeycomb is used for flow conditioning in pipes. A photo of aluminium honeycomb is given in **Figure Q2**, along with a sketch of the time-averaged flow through the honeycomb. The honeycomb is placed in a pipe with its holes parallel to the pipe axis and stretching across the entire cross section. Downstream of the honeycomb the flow is non-uniform, with a velocity profile $u_1(y)$.\n\n![pictureTag](question_001_Flow_Conditioning_0001.png)\n\n**Figure Q2** – Left: honeycomb. Right: sketch of flow through honeycomb.\n\nFor the simplified two-dimensional flow in **Figure Q2**, assume that:\n- The plates have negligible thickness and have a length, $L$.\n- The plates are separated by a distance, $h$.\n- The fluid has kinematic viscosity, $\\nu$.\n- The upstream flow is uniform at a speed $U_0$.', 'parts': [{'answerContent': '', 'content': 'List the assumptions necessary to apply the Blasius solution to the boundary layer equations.', 'orderNumber': 0, 'responseAreas': [], 'tutorial': [], 'universalPartId': 'N/A', 'workedSolution': {'content': '**Assumptions:**\n\n- **Fluid:** Continuum, Newtonian, uniform viscosity, no body forces.\n- **Flow:** Incompressible, uniform, steady (implying laminar) flow parallel to a flat plate, two-dimensional.\n- **Limits:** $\\mathrm{Re} \\gg 1$ and $\\delta/L \\ll 1$ (note that $\\partial^2 u/\\partial x^2 = 0$; also note that $\\partial p/\\partial y = 0$ is not an assumption). Self-similarity and the condition $\\partial^2 u/\\partial y^2$ being dominant is a reasonable alternative.', 'id': 'N/A', 'title': '', 'children': []}}, {'answerContent': '', 'content': 'Derive an expression for the thickness of the wake of each plate in **Figure Q2** in terms of $U_0$, $\\nu$, and $L$. Give a clear definition of the wake width. You may assume steady, laminar, incompressible flow.', 'orderNumber': 1, 'responseAreas': [], 'tutorial': [], 'universalPartId': 'N/A', 'workedSolution': {'content': 'The Blasius solution applies in this case.\n\nThe displacement thickness is given by the Blasius solution as\n\n$\\delta_1(x = L) = 1.72\\,L \\sqrt{\\frac{\\nu}{U_0 L}} = 1.72 \\sqrt{\\frac{\\nu L}{U_0}}$.\n\nAlternative thickness measurements include the momentum thickness or the 99% thickness.\n\nThe width of a wake is twice the width of one boundary layer.', 'id': 'N/A', 'title': '', 'children': []}}, {'answerContent': '', 'content': 'Derive an expression to estimate the maximum velocity downstream of the honeycomb, i.e. the maximum value in $u_1(y)$.', 'orderNumber': 2, 'responseAreas': [], 'tutorial': [], 'universalPartId': 'N/A', 'workedSolution': {'content': 'The mass flow rate between two plates is\n\n$\\int_0^h u(x, y) \\; dy$.\n\nUpstream the integral yields $U_0 h$ (per unit width into the page). Downstream the mass flow must be equal and is composed of the boundary layer on either side and the bulk flow. Using the displacement thickness, the effective width reduces by $2\\delta_1$, hence the central bulk velocity must increase. The mass flow rate is written as\n\n$\\int_0^h u(y) \\; dy = U_1 (h - 2\\delta_1) = U_0 h$.\n\nHence,\n\n$U_1 = \\frac{U_0 h}{h - 2\\delta_1} = U_0 \\left( 1 + \\frac{2\\delta_1}{h} + \\dots \\right)$, \n\nso that $U_1$ is the maximum velocity.', 'id': 'N/A', 'title': '', 'children': []}}, {'answerContent': '', 'content': 'The wake is likely to become unstable and break down into eddies. Sketch this phenomenon and suggest characteristic length and time scales for the eddies.', 'orderNumber': 3, 'responseAreas': [], 'tutorial': [], 'universalPartId': 'N/A', 'workedSolution': {'content': "*Sketch:*\n\n![pictureTag](question_001_Flow_Conditioning_0002.png)\n\nA suggested sketch would include the length $h$ and the velocity $U_0$. (Reference may be made to $k$, $\\varepsilon$, or $U'$ and the timescale $L_t/U_t$, so in this case $h/U_0$.)\n\nStudents may  ...
#
# INFO: writing pastpapers/json_combined/set_fluid_mechanics_2023/question_001_Flow_Conditioning.json
# **Question 3**:
# {'title': 'Atmospheric Entry', 'workedSolutions': [' **(a)**\n\nThe following assumptions are made:\n\n1. Continuum  \n2. Inviscid  \n3. Steady  \n4. Flow along a streamline  \n5. Perfect gas  \n6. Isentropic process  \n7. No body forces  \n\nOne mark is given per assumption for the first five. If all seven are listed, then an additional mark is awarded.', ' **(b)**\n\nWe can use the isentropic flow relations to calculate the stagnation temperature with $M = 3.5$, $T_e = 169\\,K$, and $\\gamma = 1.4$:\n\n$T_0 = T_e\\left(1 + \\frac{\\gamma - 1}{2}M_e^2\\right) = 169\\,(1 + 0.2 \\times 3.5^2) = 583\\,K$.', ' **(c)**\n\nThis was an open question and all answers were marked on their merit. The marking guidelines were:\n\n- Refer to an assumption (listed in part (a)).\n- Refer to a relevant dimensionless number.\n- Correctly conclude (full marks if the answer is quantitative).\n- Additional marks were available for responses that combined the above or provided a more in-depth explanation.\n\n*Example answer structure (each line is an example worth 6 marks, plus two if calculations or further discussion were given):*\n\n| Assumption     | Quantity                         | Geometry                | Conclusion                                                                                                                                         |\n|----------------|----------------------------------|-------------------------|----------------------------------------------------------------------------------------------------------------------------------------------------|\n| Continuum      | Knudsen Number                   | $\\rho R T/p$            | Must be $\\ll 1$.                                                                                                                                   |\n| Inviscid       | Reynolds Number                  | $\\rho C_p c^2 T/k$       | May not be applicable.                                                                                                                             |\n| Steady         | $\\Delta t/T$                     |                         | Must be $\\gg 1$; only valid at the front but not the rear, even if Re is high.                                                                    |\n| Streamline     |                                  |                         | Quasi-steady is reasonable based on the time scale of changes relative to the timescale of interest.                                               |\n| Perfect Gas    |                                  |                         | Turbulent fluctuations are unlikely to be present on the upstream side.                                                                          |\n| Isentropic     |                                  |                         | Reasonable – or simply calculate the relevant parameter $R$. The values may differ significantly so that the relation might not be practically applicable.  |\n| Body Forces    | $\\rho g h/(p_0-p_e)$             |                         | Negligible.\n\n*Note:* The full table and additional detailed marking comments are provided in the original exam script.']}
#
# INFO: Get question name.
# INFO: reading pastpapers/json/ans_me2fmx_2023_exam-paper_solutions_2023/question_002_Atmospheric_Entry.json
# INFO: ans_workedSolution: The following assumptions are made:
#
# 1. Continuum
# 2. Inviscid
# 3. Steady
# 4. Flow along a streamline
# 5. Perfect gas
# 6. Isentropic process
# 7. No body forces
#
# One mark is given per assumption for the first five. If all seven are listed, then an additional mark is awarded.
# INFO:orderNumber 0 matched, merged workedSolution: {'content': 'The following assumptions are made:\n\n1. Continuum  \n2. Inviscid  \n3. Steady  \n4. Flow along a streamline  \n5. Perfect gas  \n6. Isentropic process  \n7. No body forces  \n\nOne mark is given per assumption for the first five. If all seven are listed, then an additional mark is awarded.', 'id': 'N/A', 'title': '', 'children': []}
# INFO: ans_workedSolution: We can use the isentropic flow relations to calculate the stagnation temperature with $M = 3.5$, $T_e = 169\,K$, and $\gamma = 1.4$:
#
# $T_0 = T_e\left(1 + \frac{\gamma - 1}{2}M_e^2\right) = 169\,(1 + 0.2 \times 3.5^2) = 583\,K$.
# INFO:orderNumber 1 matched, merged workedSolution: {'content': 'We can use the isentropic flow relations to calculate the stagnation temperature with $M = 3.5$, $T_e = 169\\,K$, and $\\gamma = 1.4$:\n\n$T_0 = T_e\\left(1 + \\frac{\\gamma - 1}{2}M_e^2\\right) = 169\\,(1 + 0.2 \\times 3.5^2) = 583\\,K$.', 'id': 'N/A', 'title': '', 'children': []}
# INFO: ans_workedSolution: This was an open question and all answers were marked on their merit. The marking guidelines were:
#
# - Refer to an assumption (listed in part (a)).
# - Refer to a relevant dimensionless number.
# - Correctly conclude (full marks if the answer is quantitative).
# - Additional marks were available for responses that combined the above or provided a more in-depth explanation.
#
# *Example answer structure (each line is an example worth 6 marks, plus two if calculations or further discussion were given):*
#
# | Assumption     | Quantity                         | Geometry                | Conclusion                                                                                                                                         |
# |----------------|----------------------------------|-------------------------|----------------------------------------------------------------------------------------------------------------------------------------------------|
# | Continuum      | Knudsen Number                   | $\rho R T/p$            | Must be $\ll 1$.                                                                                                                                   |
# | Inviscid       | Reynolds Number                  | $\rho C_p c^2 T/k$       | May not be applicable.                                                                                                                             |
# | Steady         | $\Delta t/T$                     |                         | Must be $\gg 1$; only valid at the front but not the rear, even if Re is high.                                                                    |
# | Streamline     |                                  |                         | Quasi-steady is reasonable based on the time scale of changes relative to the timescale of interest.                                               |
# | Perfect Gas    |                                  |                         | Turbulent fluctuations are unlikely to be present on the upstream side.                                                                          |
# | Isentropic     |                                  |                         | Reasonable – or simply calculate the relevant parameter $R$. The values may differ significantly so that the relation might not be practically applicable.  |
# | Body Forces    | $\rho g h/(p_0-p_e)$             |                         | Negligible.
#
# *Note:* The full table and additional detailed marking comments are provided in the original exam script.
# INFO:orderNumber 2 matched, merged workedSolution: {'content': 'This was an open question and all answers were marked on their merit. The marking guidelines were:\n\n- Refer to an assumption (listed in part (a)).\n- Refer to a relevant dimensionless number.\n- Correctly conclude (full marks if the answer is quantitative).\n- Additional marks were available for responses that combined the above or provided a more in-depth explanation.\n\n*Example answer structure (each line is an example worth 6 marks, plus two if calculations or further discussion were given):*\n\n| Assumption     | Quantity                         | Geometry                | Conclusion                                                                                                                                         |\n|----------------|----------------------------------|-------------------------|----------------------------------------------------------------------------------------------------------------------------------------------------|\n| Continuum      | Knudsen Number                   | $\\rho R T/p$            | Must be $\\ll 1$.                                                                                                                                   |\n| Inviscid       | Reynolds Number                  | $\\rho C_p c^2 T/k$       | May not be applicable.                                                                                                                             |\n| Steady         | $\\Delta t/T$                     |                         | Must be $\\gg 1$; only valid at the front but not the rear, even if Re is high.                                                                    |\n| Streamline     |                                  |                         | Quasi-steady is reasonable based on the time scale of changes relative to the timescale of interest.                                               |\n| Perfect Gas    |                                  |                         | Turbulent fluctuations are unlikely to be present on the upstream side.                                                                          |\n| Isentropic     |                                  |                         | Reasonable – or simply calculate the relevant parameter $R$. The values may differ significantly so that the relation might not be practically applicable.  |\n| Body Forces    | $\\rho g h/(p_0-p_e)$             |                         | Negligible.\n\n*Note:* The full table and additional detailed marking comments are provided in the original exam script.', 'id': 'N/A', 'title': '', 'children': []}
# INFO: JSON 3:
# {'orderNumber': 2, 'displayFinalAnswer': True, 'displayStructuredTutorial': True, 'displayWorkedSolution': True, 'masterContent': 'A spacecraft enters the atmosphere and the stagnation conditions on the leading face of the spacecraft need to be predicted. At an altitude of 100 km, the air has a pressure of $0.0289$ Pa, a density of $5 \\times 10^{-7}$ kg/m$^3$, a temperature of $169$ K and a ratio of specific heats $\\gamma = 1.4$.\n\n![pictureTag](question_002_Atmospheric_Entry_0001.png)\n\n**Figure Q3 –** The Apollo spacecraft entering the atmosphere.', 'parts': [{'answerContent': '', 'content': 'List the assumptions required to apply the isentropic flow relations to this problem.', 'orderNumber': 0, 'responseAreas': [], 'tutorial': [], 'universalPartId': 'N/A', 'workedSolution': {'content': 'The following assumptions are made:\n\n1. Continuum  \n2. Inviscid  \n3. Steady  \n4. Flow along a streamline  \n5. Perfect gas  \n6. Isentropic process  \n7. No body forces  \n\nOne mark is given per assumption for the first five. If all seven are listed, then an additional mark is awarded.', 'id': 'N/A', 'title': '', 'children': []}}, {'answerContent': '', 'content': 'At Mach 3.5 estimate the maximum temperature on the spacecraft.', 'orderNumber': 1, 'responseAreas': [], 'tutorial': [], 'universalPartId': 'N/A', 'workedSolution': {'content': 'We can use the isentropic flow relations to calculate the stagnation temperature with $M = 3.5$, $T_e = 169\\,K$, and $\\gamma = 1.4$:\n\n$T_0 = T_e\\left(1 + \\frac{\\gamma - 1}{2}M_e^2\\right) = 169\\,(1 + 0.2 \\times 3.5^2) = 583\\,K$.', 'id': 'N/A', 'title': '', 'children': []}}, {'answerContent': '', 'content': 'Comment on the applicability of the isentropic flow relations to this problem. Where relevant, refer to a dimensionless group.', 'orderNumber': 2, 'responseAreas': [], 'tutorial': [], 'universalPartId': 'N/A', 'workedSolution': {'content': 'This was an open question and all answers were marked on their merit. The marking guidelines were:\n\n- Refer to an assumption (listed in part (a)).\n- Refer to a relevant dimensionless number.\n- Correctly conclude (full marks if the answer is quantitative).\n- Additional marks were available for responses that combined the above or provided a more in-depth explanation.\n\n*Example answer structure (each line is an example worth 6 marks, plus two if calculations or further discussion were given):*\n\n| Assumption     | Quantity                         | Geometry                | Conclusion                                                                                                                                         |\n|----------------|----------------------------------|-------------------------|----------------------------------------------------------------------------------------------------------------------------------------------------|\n| Continuum      | Knudsen Number                   | $\\rho R T/p$            | Must be $\\ll 1$.                                                                                                                                   |\n| Inviscid       | Reynolds Number                  | $\\rho C_p c^2 T/k$       | May not be applicable.                                                                                                                             |\n| Steady         | $\\Delta t/T$                     |                         | Must be $\\gg 1$; only valid at the front but not the rear, even if Re is high.                                                                    |\n| Streamline     |                                  |                         | Quasi-steady is reasonable based on the time scale of changes relative to the timescale of interest.                                               |\n| Perfect Gas    |                                  |                         | Turbulent fluctuations are unlikely to be present on the upstream side.                                         ...
#
# INFO: writing pastpapers/json_combined/set_fluid_mechanics_2023/question_002_Atmospheric_Entry.json
